# %%
dirname = "/Users/gc3045/scmail_v1/sc-mail-experiments/Real_biodata/TLSCL/bar12"

# %%
prior_file = f"{dirname}/Bar12_priors.pickle"
msa_file = f"{dirname}/Bar12_character_matrix.txt"
tree_file = f"/Users/gc3045/scmail_v1/sc-mail-experiments/Real_biodata/TLSCL/viz/Bar12_trees.nwk"
lentiviral_barcode_label_file = f"{dirname}/Bar12_labels.csv"
metadata_file = "/Users/gc3045/scmail_v1/tls_data/TLS_metadata/Bar12_metadata.txt"

# %%
from laml_libs.sequence_lib import read_sequences, read_priors
from treeswift import read_tree_newick

# %%
t = read_tree_newick(tree_file)

# %%
# p = read_priors(prior_file)
# msa, site_names = read_sequences(msa_file, delimiter="\t")

# %%
import pandas as pd

df = pd.read_csv(metadata_file, delimiter='\t')
df.index = df['cellBC']

# %%
df
# Out:
#                                 cellBC  intBC   UMI        cell_state
# cellBC
# AAACCCAGTCTCTCAC-1  AAACCCAGTCTCTCAC-1      8  1107   ['NeuralTube1']  \
# AAAGGATTCGCACGAC-1  AAAGGATTCGCACGAC-1      7  1004          ['NMPs']
# AAAGGTAAGAATTGTG-1  AAAGGTAAGAATTGTG-1      7  1593          ['NMPs']
# AAAGGTATCAATGTCG-1  AAAGGTATCAATGTCG-1      9  2045          ['NMPs']
# AAAGGTATCGACTCCT-1  AAAGGTATCGACTCCT-1      6   453  ['SomiteSclero']
# ...                                ...    ...   ...               ...
# TTTCATGCAGCACGAA-1  TTTCATGCAGCACGAA-1      8   796        ['Somite']
# TTTCGATTCACCATAG-1  TTTCGATTCACCATAG-1      7   377          ['NMPs']
# TTTCGATTCTCGCCTA-1  TTTCGATTCTCGCCTA-1      8  1791          ['NMPs']
# TTTGACTAGCGTCAAG-1  TTTGACTAGCGTCAAG-1      8   723          ['NMPs']
# TTTGGAGGTCGTCATA-1  TTTGGAGGTCGTCATA-1      9   868          ['pPSM']
#
#                      StF_Group
# cellBC
# AAACCCAGTCTCTCAC-1   ['StF_2']
# AAAGGATTCGCACGAC-1   ['empty']
# AAAGGTAAGAATTGTG-1   ['StF_4']
# AAAGGTATCAATGTCG-1   ['empty']
# AAAGGTATCGACTCCT-1   ['empty']
# ...                        ...
# TTTCATGCAGCACGAA-1  ['StF_10']
# TTTCGATTCACCATAG-1  ['StF_29']
# TTTCGATTCTCGCCTA-1   ['StF_2']
# TTTGACTAGCGTCAAG-1   ['StF_4']
# TTTGGAGGTCGTCATA-1   ['StF_2']
#
# [363 rows x 5 columns]

# %%
df.cell_state.unique()
# Out:
# array(["['NeuralTube1']", "['NMPs']", "['SomiteSclero']", "['pPSM']",
#        "['Endoderm']", "['Somite']", "['SomiteDermo']", "['aPSM']",
#        "['Somite0']", "['NeuralTube2']", "['PCGLC']", "['Somite-1']"],
#       dtype=object)

# %%
import ast

for index, row in df.iterrows(): 
    # cell_state = ast.literal_eval(df.loc['TTTCATGCAGCACGAA-1','cell_state'])
    cell_state = ast.literal_eval(row['cell_state'])

    print(cell_state)
# Out:
# ['NeuralTube1']
# ['NMPs']
# ['NMPs']
# ['NMPs']
# ['SomiteSclero']
# ['NMPs']
# ['NMPs']
# ['NeuralTube1']
# ['NMPs']
# ['pPSM']
# ['Endoderm']
# ['Somite']
# ['SomiteDermo']
# ['NeuralTube1']
# ['SomiteDermo']
# ['Somite']
# ['NMPs']
# ['NeuralTube1']
# ['NeuralTube1']
# ['NMPs']
# ['NMPs']
# ['NMPs']
# ['NMPs']
# ['NMPs']
# ['Somite']
# ['pPSM']
# ['pPSM']
# ['NMPs']
# ['NMPs']
# ['NMPs']
# ['aPSM']
# ['NeuralTube1']
# ['NMPs']
# ['NMPs']
# ['NMPs']
# ['NeuralTube1']
# ['NMPs']
# ['NMPs']
# ['NeuralTube1']
# ['NMPs']
# ['NMPs']
# ['Somite0']
# ['pPSM']
# ['pPSM']
# ['NMPs']
# ['pPSM']
# ['NMPs']
# ['NeuralTube1']
# ['NMPs']
# ['NeuralTube1']
# ['NeuralTube1']
# ['NMPs']
# ['NeuralTube1']
# ['pPSM']
# ['NMPs']
# ['NMPs']
# ['Somite']
# ['NeuralTube2']
# ['NeuralTube1']
# ['SomiteSclero']
# ['SomiteDermo']
# ['Somite']
# ['NMPs']
# ['Endoderm']
# ['NeuralTube1']
# ['aPSM']
# ['Somite']
# ['pPSM']
# ['pPSM']
# ['SomiteDermo']
# ['NMPs']
# ['NMPs']
# ['NeuralTube1']
# ['NMPs']
# ['aPSM']
# ['NMPs']
# ['pPSM']
# ['NMPs']
# ['NMPs']
# ['NMPs']
# ['aPSM']
# ['PCGLC']
# ['SomiteDermo']
# ['NMPs']
# ['Somite']
# ['NeuralTube1']
# ['NMPs']
# ['NMPs']
# ['NMPs']
# ['NeuralTube1']
# ['NMPs']
# ['NeuralTube1']
# ['pPSM']
# ['NMPs']
# ['SomiteDermo']
# ['NMPs']
# ['pPSM']
# ['NMPs']
# ['NMPs']
# ['NMPs']
# ['NMPs']
# ['pPSM']
# ['NeuralTube1']
# ['NMPs']
# ['pPSM']
# ['NMPs']
# ['pPSM']
# ['NMPs']
# ['NMPs']
# ['NeuralTube1']
# ['pPSM']
# ['SomiteSclero']
# ['NeuralTube1']
# ['NMPs']
# ['pPSM']
# ['SomiteDermo']
# ['NMPs']
# ['Somite0']
# ['aPSM']
# ['NeuralTube1']
# ['NeuralTube1']
# ['NeuralTube1']
# ['NMPs']
# ['NMPs']
# ['NMPs']
# ['NMPs']
# ['Endoderm']
# ['pPSM']
# ['NMPs']
# ['pPSM']
# ['NeuralTube1']
# ['NMPs']
# ['Somite']
# ['NMPs']
# ['Somite']
# ['NMPs']
# ['NeuralTube1']
# ['aPSM']
# ['NMPs']
# ['NMPs']
# ['NMPs']
# ['NeuralTube1']
# ['aPSM']
# ['NMPs']
# ['NMPs']
# ['Somite0']
# ['NMPs']
# ['NeuralTube1']
# ['NMPs']
# ['NMPs']
# ['NeuralTube1']
# ['NMPs']
# ['NMPs']
# ['NMPs']
# ['NMPs']
# ['NeuralTube1']
# ['Somite']
# ['NMPs']
# ['NMPs']
# ['pPSM']
# ['NMPs']
# ['NeuralTube1']
# ['NMPs']
# ['pPSM']
# ['pPSM']
# ['aPSM']
# ['NMPs']
# ['NMPs']
# ['Somite0']
# ['NMPs']
# ['NMPs']
# ['NeuralTube1']
# ['NMPs']
# ['SomiteSclero']
# ['pPSM']
# ['Somite']
# ['NMPs']
# ['NMPs']
# ['NMPs']
# ['pPSM']
# ['SomiteDermo']
# ['NMPs']
# ['Somite0']
# ['NMPs']
# ['NMPs']
# ['Somite']
# ['SomiteDermo']
# ['NMPs']
# ['SomiteSclero']
# ['NMPs']
# ['Somite']
# ['SomiteSclero']
# ['NMPs']
# ['NMPs']
# ['NMPs']
# ['Somite']
# ['pPSM']
# ['NMPs']
# ['NeuralTube1']
# ['NMPs']
# ['NMPs']
# ['NMPs']
# ['pPSM']
# ['NeuralTube1']
# ['NeuralTube1']
# ['pPSM']
# ['aPSM']
# ['NMPs']
# ['SomiteDermo']
# ['NeuralTube1']
# ['NeuralTube1']
# ['NMPs']
# ['NMPs']
# ['pPSM']
# ['SomiteDermo']
# ['NMPs']
# ['NMPs']
# ['pPSM']
# ['NeuralTube1']
# ['pPSM']
# ['NMPs']
# ['NeuralTube1']
# ['NMPs']
# ['NeuralTube1']
# ['NMPs']
# ['NeuralTube1']
# ['NMPs']
# ['NeuralTube1']
# ['SomiteDermo']
# ['NMPs']
# ['aPSM']
# ['Somite']
# ['NMPs']
# ['Somite']
# ['NeuralTube1']
# ['NMPs']
# ['NMPs']
# ['NeuralTube1']
# ['NMPs']
# ['Somite']
# ['NeuralTube1']
# ['NMPs']
# ['pPSM']
# ['NMPs']
# ['NeuralTube1']
# ['NeuralTube1']
# ['NeuralTube1']
# ['pPSM']
# ['NeuralTube1']
# ['SomiteSclero']
# ['NMPs']
# ['NMPs']
# ['NeuralTube1']
# ['pPSM']
# ['NMPs']
# ['NMPs']
# ['NeuralTube1']
# ['NeuralTube1']
# ['NMPs']
# ['aPSM']
# ['pPSM']
# ['NMPs']
# ['NMPs']
# ['NeuralTube1']
# ['SomiteDermo']
# ['NMPs']
# ['NMPs']
# ['aPSM']
# ['SomiteDermo']
# ['SomiteDermo']
# ['NMPs']
# ['pPSM']
# ['NMPs']
# ['aPSM']
# ['NMPs']
# ['NMPs']
# ['NMPs']
# ['NMPs']
# ['NeuralTube1']
# ['NeuralTube1']
# ['pPSM']
# ['SomiteSclero']
# ['NeuralTube1']
# ['NMPs']
# ['aPSM']
# ['NMPs']
# ['NMPs']
# ['NMPs']
# ['pPSM']
# ['pPSM']
# ['NeuralTube1']
# ['pPSM']
# ['NMPs']
# ['Somite-1']
# ['Somite']
# ['NMPs']
# ['NMPs']
# ['NeuralTube1']
# ['SomiteDermo']
# ['NMPs']
# ['NeuralTube1']
# ['NeuralTube1']
# ['SomiteDermo']
# ['aPSM']
# ['NMPs']
# ['NMPs']
# ['NMPs']
# ['NeuralTube1']
# ['Endoderm']
# ['Somite']
# ['NMPs']
# ['SomiteDermo']
# ['NeuralTube1']
# ['NeuralTube1']
# ['NeuralTube1']
# ['SomiteDermo']
# ['SomiteDermo']
# ['NMPs']
# ['NeuralTube1']
# ['NMPs']
# ['NMPs']
# ['NeuralTube1']
# ['NMPs']
# ['pPSM']
# ['pPSM']
# ['pPSM']
# ['pPSM']
# ['pPSM']
# ['SomiteSclero']
# ['NeuralTube1']
# ['NMPs']
# ['NeuralTube1']
# ['Endoderm']
# ['NeuralTube1']
# ['pPSM']
# ['NMPs']
# ['NMPs']
# ['NeuralTube1']
# ['NMPs']
# ['NeuralTube1']
# ['NMPs']
# ['NMPs']
# ['NeuralTube1']
# ['NeuralTube1']
# ['Somite']
# ['Somite']
# ['SomiteDermo']
# ['pPSM']
# ['NMPs']
# ['NMPs']
# ['NeuralTube1']
# ['SomiteSclero']
# ['NMPs']
# ['NeuralTube1']
# ['pPSM']
# ['Somite']
# ['Somite']
# ['pPSM']
# ['Somite']
# ['NMPs']
# ['NMPs']
# ['NMPs']
# ['pPSM']

# %%
dev_tree_str = '(PCGLC:1,(Endothelial:1,(Endoderm:1,(((NeuralTube2:1)NeuralTube1:1,(((((SomiteDermo:1,SomiteSclero:1)Somite:1)Somite0:1)Somite-1:1)pPSM:1)aPSM:1)NMPs:1)Prog-derm-NMPs:1)Prog-lial-derm:1)Prog-PGCLC-lial:1)Prog;'
dev_tree = read_tree_newick(dev_tree_str)

# %%
dev_tree.draw(show_labels=True)

# %%
dev_tree.num_nodes()
# Out:
# 17

# %%
for node in dev_tree.traverse_postorder():
    print(node.label)
# Out:
# PCGLC
# Endothelial
# Endoderm
# NeuralTube2
# NeuralTube1
# SomiteDermo
# SomiteSclero
# Somite
# Somite0
# Somite-1
# pPSM
# aPSM
# NMPs
# Prog-derm-NMPs
# Prog-lial-derm
# Prog-PGCLC-lial
# Prog

# %%
all_cell_states = []
for n in dev_tree.traverse_postorder():
    if n.label is not None:
        all_cell_states.append(n.label)
all_cell_states
# Out:
# ['PCGLC',
#  'Endothelial',
#  'Endoderm',
#  'NeuralTube2',
#  'NeuralTube1',
#  'SomiteDermo',
#  'SomiteSclero',
#  'Somite',
#  'Somite0',
#  'Somite-1',
#  'pPSM',
#  'aPSM',
#  'NMPs',
#  'Prog-derm-NMPs',
#  'Prog-lial-derm',
#  'Prog-PGCLC-lial',
#  'Prog']

# %%
# get LCA assignment given cell states
def get_lca(tree, states):
    return tree.mrca(states)

# %%
mrca = get_lca(dev_tree, ['SomiteDermo', 'NeuralTube2'])
mrca.label
# Out:
# 'NMPs'

# %%
for node in t.traverse_postorder():
    if node.is_leaf():
        node.cell_state = ast.literal_eval(df.loc[node.label,'cell_state'])[0]
        # print("leaf cell state", node.cell_state)
    else:
        # get children
        child_cell_states = [c.cell_state for c in node.children]
        # print(child_cell_states)
        node.cell_state = get_lca(dev_tree, child_cell_states).label
        if node.cell_state is None:
            print(child_cell_states)

# %%
# check if all

# %%
import numpy as np

num_intervals = 1000
intervals = np.linspace(0, 1, 1000, endpoint=False)
interval_dict = {}
for interval in intervals:
    interval_dict[interval] = {}
    for cell_state in all_cell_states:
        interval_dict[interval][cell_state] = 0

# %%
t

# %%
# get the proportion of lineages 
# in each cell state 
for node in t.traverse_preorder():
    if node != t.root:
        branch_start = t.distance_between(t.root, node.get_parent())
        branch_end = t.distance_between(t.root, node)
        branch_interval = pd.Interval(branch_start, branch_end, closed='both')
        
        # start_cell_state = node.get_parent().cell_state
        end_cell_state = node.cell_state
        # print(end_cell_state)
        # print(branch_interval)
        for i, interval_start in enumerate(intervals[:-1]):
            interval_end = intervals[i+1]
            interval = pd.Interval(interval_start, interval_end, closed='both')
            if interval.overlaps(branch_interval):
                interval_dict[interval_start][end_cell_state] += 1


        ##start_cell_state = node.get_parent().cell_state
        ## end_cell_state = node.cell_state
        #if start_cell_state != end_cell_state:
        #    print(','.join([str(node_time), str(start_cell_state), str(end_cell_state)]))

# %%
interval_dict
# Out:
# {0.0: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 0,
#   'Somite-1': 0,
#   'pPSM': 0,
#   'aPSM': 0,
#   'NMPs': 0,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 0,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.001: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 0,
#   'Somite-1': 0,
#   'pPSM': 0,
#   'aPSM': 0,
#   'NMPs': 0,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 0,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.002: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 0,
#   'Somite-1': 0,
#   'pPSM': 0,
#   'aPSM': 0,
#   'NMPs': 0,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 0,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.003: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 0,
#   'Somite-1': 0,
#   'pPSM': 0,
#   'aPSM': 0,
#   'NMPs': 0,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 0,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.004: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 0,
#   'Somite-1': 0,
#   'pPSM': 0,
#   'aPSM': 0,
#   'NMPs': 0,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 0,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.005: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 0,
#   'Somite-1': 0,
#   'pPSM': 0,
#   'aPSM': 0,
#   'NMPs': 0,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 0,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.006: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 0,
#   'Somite-1': 0,
#   'pPSM': 0,
#   'aPSM': 0,
#   'NMPs': 22,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 4},
#  0.007: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 0,
#   'Somite-1': 0,
#   'pPSM': 0,
#   'aPSM': 0,
#   'NMPs': 22,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.008: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 0,
#   'Somite-1': 0,
#   'pPSM': 0,
#   'aPSM': 0,
#   'NMPs': 22,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.009000000000000001: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 0,
#   'Somite-1': 0,
#   'pPSM': 0,
#   'aPSM': 0,
#   'NMPs': 22,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.01: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 0,
#   'Somite-1': 0,
#   'pPSM': 0,
#   'aPSM': 0,
#   'NMPs': 22,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.011: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 0,
#   'Somite-1': 0,
#   'pPSM': 0,
#   'aPSM': 0,
#   'NMPs': 22,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.012: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 0,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 22,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 4},
#  0.013000000000000001: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 0,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 22,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.014: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 0,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 22,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.015: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 0,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 22,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.016: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 0,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 22,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.017: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 0,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 22,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.018000000000000002: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 0,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 22,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.019: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 0,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 22,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.02: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 0,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 22,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.021: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 0,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 22,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.022: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 0,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 22,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.023: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 0,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 22,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.024: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 0,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 22,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.025: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 0,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 22,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.026000000000000002: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 0,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 22,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.027: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 0,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 22,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.028: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 0,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 22,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.029: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 0,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 22,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.03: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 0,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 22,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.031: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 0,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 22,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.032: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 0,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 22,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.033: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 0,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 22,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.034: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 0,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 22,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.035: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 0,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 22,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.036000000000000004: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 0,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 22,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.037: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 0,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 22,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.038: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 0,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 22,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.039: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 0,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 22,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.04: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 0,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 22,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.041: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 0,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 22,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.042: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 0,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 22,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.043000000000000003: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 0,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 22,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.044: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 0,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 22,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.045: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 0,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 22,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.046: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 0,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 22,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.047: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 0,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 22,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.048: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 0,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 22,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.049: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 0,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 22,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.05: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 0,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 22,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.051000000000000004: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 0,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 22,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.052000000000000005: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 0,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 22,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.053: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 0,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 22,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.054: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 0,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 22,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.055: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 0,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 22,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.056: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 0,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 22,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.057: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 24,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.058: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 22,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.059000000000000004: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 22,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.06: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 22,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.061: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 22,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.062: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 22,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.063: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 22,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.064: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 22,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.065: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 26,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.066: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 24,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.067: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 24,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.068: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 24,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.069: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 24,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.07: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 24,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.07100000000000001: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 24,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.07200000000000001: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 24,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.073: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 24,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.074: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 24,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.075: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 24,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.076: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 24,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.077: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 24,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.078: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 24,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.079: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 24,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.08: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 24,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.081: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 24,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.082: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 28,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.083: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 26,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.084: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 26,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.085: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 26,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.08600000000000001: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 26,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.08700000000000001: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 26,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.088: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 26,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.089: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 30,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.09: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 28,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.091: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 28,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.092: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 28,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.093: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 28,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.094: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 28,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.095: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 28,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.096: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 28,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.097: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 28,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.098: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 28,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.099: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 28,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.1: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 28,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.101: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 28,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.10200000000000001: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 28,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.10300000000000001: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 28,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.10400000000000001: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 30,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 8,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.105: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 30,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.106: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 30,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.107: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 30,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.108: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 30,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.109: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 30,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.11: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 2,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 34,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 8,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.111: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 2,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 32,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.112: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 2,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 32,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.113: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 2,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 32,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.114: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 2,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 32,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.115: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 2,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 32,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.116: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 2,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 32,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.117: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 2,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 32,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.11800000000000001: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 2,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 32,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.11900000000000001: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 2,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 32,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.12: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 2,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 32,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.121: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 2,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 32,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.122: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 2,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 32,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.123: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 2,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 32,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.124: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 2,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 32,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.125: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 2,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 32,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.126: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 2,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 32,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.127: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 2,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 32,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.128: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 2,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 32,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.129: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 2,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 32,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.13: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 2,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 32,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.131: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 2,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 32,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.132: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 2,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 32,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.133: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 2,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 32,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.134: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 2,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 32,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.135: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 2,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 32,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.136: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 2,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 32,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.137: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 2,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 32,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.138: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 2,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 34,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 4},
#  0.139: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 2,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 34,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.14: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 2,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 34,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.14100000000000001: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 2,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 34,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.14200000000000002: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 2,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 34,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.14300000000000002: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 2,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 34,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.14400000000000002: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 2,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 36,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 4},
#  0.145: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 2,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 36,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.146: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 2,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 36,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.147: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 2,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 36,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.148: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 2,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 36,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.149: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 2,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 36,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.15: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 2,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 36,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.151: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 2,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 38,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 4},
#  0.152: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 2,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 2,
#   'Somite-1': 0,
#   'pPSM': 2,
#   'aPSM': 0,
#   'NMPs': 38,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 6,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 2},
#  0.153: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 2,
# ...
#   'Somite0': 10,
#   'Somite-1': 2,
#   'pPSM': 90,
#   'aPSM': 30,
#   'NMPs': 308,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 0,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 0},
#  0.9510000000000001: {'PCGLC': 2,
#   'Endothelial': 0,
#   'Endoderm': 10,
#   'NeuralTube2': 2,
#   'NeuralTube1': 142,
#   'SomiteDermo': 42,
#   'SomiteSclero': 20,
#   'Somite': 46,
#   'Somite0': 10,
#   'Somite-1': 2,
#   'pPSM': 90,
#   'aPSM': 30,
#   'NMPs': 306,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 0,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 0},
#  0.9520000000000001: {'PCGLC': 2,
#   'Endothelial': 0,
#   'Endoderm': 10,
#   'NeuralTube2': 2,
#   'NeuralTube1': 142,
#   'SomiteDermo': 42,
#   'SomiteSclero': 20,
#   'Somite': 46,
#   'Somite0': 10,
#   'Somite-1': 2,
#   'pPSM': 90,
#   'aPSM': 30,
#   'NMPs': 306,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 0,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 0},
#  0.9530000000000001: {'PCGLC': 2,
#   'Endothelial': 0,
#   'Endoderm': 10,
#   'NeuralTube2': 2,
#   'NeuralTube1': 142,
#   'SomiteDermo': 42,
#   'SomiteSclero': 20,
#   'Somite': 46,
#   'Somite0': 10,
#   'Somite-1': 2,
#   'pPSM': 90,
#   'aPSM': 30,
#   'NMPs': 306,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 0,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 0},
#  0.9540000000000001: {'PCGLC': 2,
#   'Endothelial': 0,
#   'Endoderm': 10,
#   'NeuralTube2': 2,
#   'NeuralTube1': 142,
#   'SomiteDermo': 42,
#   'SomiteSclero': 20,
#   'Somite': 46,
#   'Somite0': 10,
#   'Somite-1': 2,
#   'pPSM': 90,
#   'aPSM': 30,
#   'NMPs': 306,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 0,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 0},
#  0.9550000000000001: {'PCGLC': 2,
#   'Endothelial': 0,
#   'Endoderm': 10,
#   'NeuralTube2': 2,
#   'NeuralTube1': 142,
#   'SomiteDermo': 42,
#   'SomiteSclero': 20,
#   'Somite': 46,
#   'Somite0': 10,
#   'Somite-1': 2,
#   'pPSM': 90,
#   'aPSM': 30,
#   'NMPs': 306,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 0,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 0},
#  0.9560000000000001: {'PCGLC': 2,
#   'Endothelial': 0,
#   'Endoderm': 10,
#   'NeuralTube2': 2,
#   'NeuralTube1': 142,
#   'SomiteDermo': 42,
#   'SomiteSclero': 20,
#   'Somite': 46,
#   'Somite0': 10,
#   'Somite-1': 2,
#   'pPSM': 90,
#   'aPSM': 30,
#   'NMPs': 306,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 0,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 0},
#  0.9570000000000001: {'PCGLC': 2,
#   'Endothelial': 0,
#   'Endoderm': 10,
#   'NeuralTube2': 2,
#   'NeuralTube1': 142,
#   'SomiteDermo': 42,
#   'SomiteSclero': 20,
#   'Somite': 46,
#   'Somite0': 10,
#   'Somite-1': 2,
#   'pPSM': 90,
#   'aPSM': 30,
#   'NMPs': 306,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 0,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 0},
#  0.9580000000000001: {'PCGLC': 2,
#   'Endothelial': 0,
#   'Endoderm': 10,
#   'NeuralTube2': 2,
#   'NeuralTube1': 142,
#   'SomiteDermo': 42,
#   'SomiteSclero': 20,
#   'Somite': 46,
#   'Somite0': 10,
#   'Somite-1': 2,
#   'pPSM': 90,
#   'aPSM': 30,
#   'NMPs': 306,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 0,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 0},
#  0.9590000000000001: {'PCGLC': 2,
#   'Endothelial': 0,
#   'Endoderm': 10,
#   'NeuralTube2': 2,
#   'NeuralTube1': 142,
#   'SomiteDermo': 42,
#   'SomiteSclero': 20,
#   'Somite': 46,
#   'Somite0': 10,
#   'Somite-1': 2,
#   'pPSM': 90,
#   'aPSM': 30,
#   'NMPs': 306,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 0,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 0},
#  0.96: {'PCGLC': 2,
#   'Endothelial': 0,
#   'Endoderm': 10,
#   'NeuralTube2': 2,
#   'NeuralTube1': 142,
#   'SomiteDermo': 42,
#   'SomiteSclero': 20,
#   'Somite': 46,
#   'Somite0': 10,
#   'Somite-1': 2,
#   'pPSM': 90,
#   'aPSM': 30,
#   'NMPs': 306,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 0,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 0},
#  0.961: {'PCGLC': 2,
#   'Endothelial': 0,
#   'Endoderm': 10,
#   'NeuralTube2': 2,
#   'NeuralTube1': 142,
#   'SomiteDermo': 42,
#   'SomiteSclero': 20,
#   'Somite': 46,
#   'Somite0': 10,
#   'Somite-1': 2,
#   'pPSM': 90,
#   'aPSM': 30,
#   'NMPs': 306,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 0,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 0},
#  0.962: {'PCGLC': 2,
#   'Endothelial': 0,
#   'Endoderm': 10,
#   'NeuralTube2': 2,
#   'NeuralTube1': 142,
#   'SomiteDermo': 42,
#   'SomiteSclero': 20,
#   'Somite': 46,
#   'Somite0': 10,
#   'Somite-1': 2,
#   'pPSM': 90,
#   'aPSM': 30,
#   'NMPs': 306,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 0,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 0},
#  0.963: {'PCGLC': 2,
#   'Endothelial': 0,
#   'Endoderm': 10,
#   'NeuralTube2': 2,
#   'NeuralTube1': 142,
#   'SomiteDermo': 42,
#   'SomiteSclero': 20,
#   'Somite': 46,
#   'Somite0': 10,
#   'Somite-1': 2,
#   'pPSM': 90,
#   'aPSM': 30,
#   'NMPs': 306,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 0,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 0},
#  0.964: {'PCGLC': 2,
#   'Endothelial': 0,
#   'Endoderm': 10,
#   'NeuralTube2': 2,
#   'NeuralTube1': 142,
#   'SomiteDermo': 42,
#   'SomiteSclero': 20,
#   'Somite': 46,
#   'Somite0': 10,
#   'Somite-1': 2,
#   'pPSM': 90,
#   'aPSM': 30,
#   'NMPs': 306,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 0,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 0},
#  0.965: {'PCGLC': 2,
#   'Endothelial': 0,
#   'Endoderm': 10,
#   'NeuralTube2': 2,
#   'NeuralTube1': 142,
#   'SomiteDermo': 42,
#   'SomiteSclero': 20,
#   'Somite': 46,
#   'Somite0': 10,
#   'Somite-1': 2,
#   'pPSM': 90,
#   'aPSM': 30,
#   'NMPs': 306,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 0,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 0},
#  0.966: {'PCGLC': 2,
#   'Endothelial': 0,
#   'Endoderm': 10,
#   'NeuralTube2': 2,
#   'NeuralTube1': 142,
#   'SomiteDermo': 42,
#   'SomiteSclero': 20,
#   'Somite': 46,
#   'Somite0': 10,
#   'Somite-1': 2,
#   'pPSM': 90,
#   'aPSM': 30,
#   'NMPs': 306,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 0,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 0},
#  0.967: {'PCGLC': 2,
#   'Endothelial': 0,
#   'Endoderm': 10,
#   'NeuralTube2': 2,
#   'NeuralTube1': 142,
#   'SomiteDermo': 42,
#   'SomiteSclero': 20,
#   'Somite': 46,
#   'Somite0': 10,
#   'Somite-1': 2,
#   'pPSM': 90,
#   'aPSM': 30,
#   'NMPs': 310,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 0,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 0},
#  0.968: {'PCGLC': 2,
#   'Endothelial': 0,
#   'Endoderm': 10,
#   'NeuralTube2': 2,
#   'NeuralTube1': 144,
#   'SomiteDermo': 42,
#   'SomiteSclero': 20,
#   'Somite': 46,
#   'Somite0': 10,
#   'Somite-1': 2,
#   'pPSM': 94,
#   'aPSM': 30,
#   'NMPs': 310,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 0,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 0},
#  0.969: {'PCGLC': 2,
#   'Endothelial': 0,
#   'Endoderm': 10,
#   'NeuralTube2': 2,
#   'NeuralTube1': 144,
#   'SomiteDermo': 42,
#   'SomiteSclero': 20,
#   'Somite': 46,
#   'Somite0': 10,
#   'Somite-1': 2,
#   'pPSM': 94,
#   'aPSM': 30,
#   'NMPs': 306,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 0,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 0},
#  0.97: {'PCGLC': 2,
#   'Endothelial': 0,
#   'Endoderm': 10,
#   'NeuralTube2': 2,
#   'NeuralTube1': 144,
#   'SomiteDermo': 42,
#   'SomiteSclero': 20,
#   'Somite': 46,
#   'Somite0': 10,
#   'Somite-1': 2,
#   'pPSM': 94,
#   'aPSM': 30,
#   'NMPs': 306,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 0,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 0},
#  0.971: {'PCGLC': 2,
#   'Endothelial': 0,
#   'Endoderm': 10,
#   'NeuralTube2': 2,
#   'NeuralTube1': 144,
#   'SomiteDermo': 42,
#   'SomiteSclero': 20,
#   'Somite': 46,
#   'Somite0': 10,
#   'Somite-1': 2,
#   'pPSM': 94,
#   'aPSM': 30,
#   'NMPs': 306,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 0,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 0},
#  0.972: {'PCGLC': 2,
#   'Endothelial': 0,
#   'Endoderm': 10,
#   'NeuralTube2': 2,
#   'NeuralTube1': 144,
#   'SomiteDermo': 42,
#   'SomiteSclero': 20,
#   'Somite': 46,
#   'Somite0': 10,
#   'Somite-1': 2,
#   'pPSM': 94,
#   'aPSM': 30,
#   'NMPs': 306,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 0,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 0},
#  0.973: {'PCGLC': 2,
#   'Endothelial': 0,
#   'Endoderm': 10,
#   'NeuralTube2': 2,
#   'NeuralTube1': 144,
#   'SomiteDermo': 42,
#   'SomiteSclero': 20,
#   'Somite': 46,
#   'Somite0': 10,
#   'Somite-1': 2,
#   'pPSM': 94,
#   'aPSM': 30,
#   'NMPs': 306,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 0,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 0},
#  0.974: {'PCGLC': 2,
#   'Endothelial': 0,
#   'Endoderm': 10,
#   'NeuralTube2': 2,
#   'NeuralTube1': 144,
#   'SomiteDermo': 42,
#   'SomiteSclero': 20,
#   'Somite': 46,
#   'Somite0': 10,
#   'Somite-1': 2,
#   'pPSM': 94,
#   'aPSM': 30,
#   'NMPs': 306,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 0,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 0},
#  0.975: {'PCGLC': 2,
#   'Endothelial': 0,
#   'Endoderm': 10,
#   'NeuralTube2': 2,
#   'NeuralTube1': 144,
#   'SomiteDermo': 42,
#   'SomiteSclero': 20,
#   'Somite': 46,
#   'Somite0': 10,
#   'Somite-1': 2,
#   'pPSM': 94,
#   'aPSM': 30,
#   'NMPs': 306,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 0,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 0},
#  0.976: {'PCGLC': 2,
#   'Endothelial': 0,
#   'Endoderm': 10,
#   'NeuralTube2': 2,
#   'NeuralTube1': 144,
#   'SomiteDermo': 42,
#   'SomiteSclero': 20,
#   'Somite': 46,
#   'Somite0': 10,
#   'Somite-1': 2,
#   'pPSM': 94,
#   'aPSM': 30,
#   'NMPs': 306,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 0,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 0},
#  0.977: {'PCGLC': 2,
#   'Endothelial': 0,
#   'Endoderm': 10,
#   'NeuralTube2': 2,
#   'NeuralTube1': 144,
#   'SomiteDermo': 42,
#   'SomiteSclero': 20,
#   'Somite': 46,
#   'Somite0': 10,
#   'Somite-1': 2,
#   'pPSM': 94,
#   'aPSM': 30,
#   'NMPs': 306,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 0,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 0},
#  0.978: {'PCGLC': 2,
#   'Endothelial': 0,
#   'Endoderm': 10,
#   'NeuralTube2': 2,
#   'NeuralTube1': 144,
#   'SomiteDermo': 42,
#   'SomiteSclero': 20,
#   'Somite': 46,
#   'Somite0': 10,
#   'Somite-1': 2,
#   'pPSM': 94,
#   'aPSM': 30,
#   'NMPs': 306,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 0,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 0},
#  0.979: {'PCGLC': 2,
#   'Endothelial': 0,
#   'Endoderm': 10,
#   'NeuralTube2': 2,
#   'NeuralTube1': 144,
#   'SomiteDermo': 42,
#   'SomiteSclero': 20,
#   'Somite': 46,
#   'Somite0': 10,
#   'Somite-1': 2,
#   'pPSM': 94,
#   'aPSM': 30,
#   'NMPs': 306,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 0,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 0},
#  0.98: {'PCGLC': 2,
#   'Endothelial': 0,
#   'Endoderm': 10,
#   'NeuralTube2': 2,
#   'NeuralTube1': 144,
#   'SomiteDermo': 42,
#   'SomiteSclero': 20,
#   'Somite': 46,
#   'Somite0': 10,
#   'Somite-1': 2,
#   'pPSM': 94,
#   'aPSM': 30,
#   'NMPs': 306,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 0,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 0},
#  0.981: {'PCGLC': 2,
#   'Endothelial': 0,
#   'Endoderm': 10,
#   'NeuralTube2': 2,
#   'NeuralTube1': 144,
#   'SomiteDermo': 42,
#   'SomiteSclero': 20,
#   'Somite': 46,
#   'Somite0': 10,
#   'Somite-1': 2,
#   'pPSM': 94,
#   'aPSM': 30,
#   'NMPs': 306,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 0,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 0},
#  0.982: {'PCGLC': 2,
#   'Endothelial': 0,
#   'Endoderm': 10,
#   'NeuralTube2': 2,
#   'NeuralTube1': 144,
#   'SomiteDermo': 42,
#   'SomiteSclero': 20,
#   'Somite': 46,
#   'Somite0': 10,
#   'Somite-1': 2,
#   'pPSM': 94,
#   'aPSM': 30,
#   'NMPs': 306,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 0,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 0},
#  0.983: {'PCGLC': 2,
#   'Endothelial': 0,
#   'Endoderm': 10,
#   'NeuralTube2': 2,
#   'NeuralTube1': 144,
#   'SomiteDermo': 42,
#   'SomiteSclero': 20,
#   'Somite': 46,
#   'Somite0': 10,
#   'Somite-1': 2,
#   'pPSM': 94,
#   'aPSM': 30,
#   'NMPs': 306,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 0,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 0},
#  0.984: {'PCGLC': 2,
#   'Endothelial': 0,
#   'Endoderm': 10,
#   'NeuralTube2': 2,
#   'NeuralTube1': 144,
#   'SomiteDermo': 42,
#   'SomiteSclero': 20,
#   'Somite': 46,
#   'Somite0': 10,
#   'Somite-1': 2,
#   'pPSM': 94,
#   'aPSM': 30,
#   'NMPs': 306,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 0,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 0},
#  0.985: {'PCGLC': 2,
#   'Endothelial': 0,
#   'Endoderm': 10,
#   'NeuralTube2': 2,
#   'NeuralTube1': 144,
#   'SomiteDermo': 42,
#   'SomiteSclero': 20,
#   'Somite': 46,
#   'Somite0': 10,
#   'Somite-1': 2,
#   'pPSM': 94,
#   'aPSM': 30,
#   'NMPs': 306,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 0,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 0},
#  0.986: {'PCGLC': 2,
#   'Endothelial': 0,
#   'Endoderm': 10,
#   'NeuralTube2': 2,
#   'NeuralTube1': 144,
#   'SomiteDermo': 42,
#   'SomiteSclero': 20,
#   'Somite': 46,
#   'Somite0': 10,
#   'Somite-1': 2,
#   'pPSM': 94,
#   'aPSM': 30,
#   'NMPs': 306,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 0,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 0},
#  0.987: {'PCGLC': 2,
#   'Endothelial': 0,
#   'Endoderm': 10,
#   'NeuralTube2': 2,
#   'NeuralTube1': 144,
#   'SomiteDermo': 42,
#   'SomiteSclero': 20,
#   'Somite': 46,
#   'Somite0': 10,
#   'Somite-1': 2,
#   'pPSM': 94,
#   'aPSM': 30,
#   'NMPs': 310,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 0,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 0},
#  0.988: {'PCGLC': 2,
#   'Endothelial': 0,
#   'Endoderm': 10,
#   'NeuralTube2': 2,
#   'NeuralTube1': 144,
#   'SomiteDermo': 42,
#   'SomiteSclero': 20,
#   'Somite': 46,
#   'Somite0': 10,
#   'Somite-1': 2,
#   'pPSM': 94,
#   'aPSM': 30,
#   'NMPs': 308,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 0,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 0},
#  0.989: {'PCGLC': 2,
#   'Endothelial': 0,
#   'Endoderm': 10,
#   'NeuralTube2': 2,
#   'NeuralTube1': 144,
#   'SomiteDermo': 42,
#   'SomiteSclero': 20,
#   'Somite': 46,
#   'Somite0': 10,
#   'Somite-1': 2,
#   'pPSM': 94,
#   'aPSM': 30,
#   'NMPs': 308,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 0,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 0},
#  0.99: {'PCGLC': 2,
#   'Endothelial': 0,
#   'Endoderm': 10,
#   'NeuralTube2': 2,
#   'NeuralTube1': 144,
#   'SomiteDermo': 42,
#   'SomiteSclero': 20,
#   'Somite': 46,
#   'Somite0': 10,
#   'Somite-1': 2,
#   'pPSM': 94,
#   'aPSM': 30,
#   'NMPs': 308,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 0,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 0},
#  0.991: {'PCGLC': 2,
#   'Endothelial': 0,
#   'Endoderm': 10,
#   'NeuralTube2': 2,
#   'NeuralTube1': 144,
#   'SomiteDermo': 42,
#   'SomiteSclero': 20,
#   'Somite': 46,
#   'Somite0': 10,
#   'Somite-1': 2,
#   'pPSM': 94,
#   'aPSM': 30,
#   'NMPs': 308,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 0,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 0},
#  0.992: {'PCGLC': 2,
#   'Endothelial': 0,
#   'Endoderm': 10,
#   'NeuralTube2': 2,
#   'NeuralTube1': 144,
#   'SomiteDermo': 42,
#   'SomiteSclero': 20,
#   'Somite': 46,
#   'Somite0': 10,
#   'Somite-1': 2,
#   'pPSM': 94,
#   'aPSM': 30,
#   'NMPs': 308,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 0,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 0},
#  0.993: {'PCGLC': 2,
#   'Endothelial': 0,
#   'Endoderm': 10,
#   'NeuralTube2': 2,
#   'NeuralTube1': 154,
#   'SomiteDermo': 42,
#   'SomiteSclero': 20,
#   'Somite': 50,
#   'Somite0': 10,
#   'Somite-1': 2,
#   'pPSM': 98,
#   'aPSM': 30,
#   'NMPs': 322,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 0,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 0},
#  0.994: {'PCGLC': 2,
#   'Endothelial': 0,
#   'Endoderm': 10,
#   'NeuralTube2': 2,
#   'NeuralTube1': 150,
#   'SomiteDermo': 42,
#   'SomiteSclero': 20,
#   'Somite': 48,
#   'Somite0': 10,
#   'Somite-1': 2,
#   'pPSM': 98,
#   'aPSM': 30,
#   'NMPs': 312,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 0,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 0},
#  0.995: {'PCGLC': 2,
#   'Endothelial': 0,
#   'Endoderm': 10,
#   'NeuralTube2': 2,
#   'NeuralTube1': 150,
#   'SomiteDermo': 42,
#   'SomiteSclero': 20,
#   'Somite': 48,
#   'Somite0': 10,
#   'Somite-1': 2,
#   'pPSM': 98,
#   'aPSM': 30,
#   'NMPs': 312,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 0,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 0},
#  0.996: {'PCGLC': 2,
#   'Endothelial': 0,
#   'Endoderm': 10,
#   'NeuralTube2': 2,
#   'NeuralTube1': 150,
#   'SomiteDermo': 42,
#   'SomiteSclero': 20,
#   'Somite': 48,
#   'Somite0': 10,
#   'Somite-1': 2,
#   'pPSM': 98,
#   'aPSM': 30,
#   'NMPs': 312,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 0,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 0},
#  0.997: {'PCGLC': 2,
#   'Endothelial': 0,
#   'Endoderm': 10,
#   'NeuralTube2': 2,
#   'NeuralTube1': 150,
#   'SomiteDermo': 42,
#   'SomiteSclero': 20,
#   'Somite': 48,
#   'Somite0': 10,
#   'Somite-1': 2,
#   'pPSM': 98,
#   'aPSM': 30,
#   'NMPs': 312,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 0,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 0},
#  0.998: {'PCGLC': 2,
#   'Endothelial': 0,
#   'Endoderm': 10,
#   'NeuralTube2': 2,
#   'NeuralTube1': 150,
#   'SomiteDermo': 42,
#   'SomiteSclero': 20,
#   'Somite': 48,
#   'Somite0': 10,
#   'Somite-1': 2,
#   'pPSM': 98,
#   'aPSM': 30,
#   'NMPs': 312,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 0,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 0},
#  0.999: {'PCGLC': 0,
#   'Endothelial': 0,
#   'Endoderm': 0,
#   'NeuralTube2': 0,
#   'NeuralTube1': 0,
#   'SomiteDermo': 0,
#   'SomiteSclero': 0,
#   'Somite': 0,
#   'Somite0': 0,
#   'Somite-1': 0,
#   'pPSM': 0,
#   'aPSM': 0,
#   'NMPs': 0,
#   'Prog-derm-NMPs': 0,
#   'Prog-lial-derm': 0,
#   'Prog-PGCLC-lial': 0,
#   'Prog': 0}}

# %%
for interval_start in interval_dict:
    plt

# %%
with open("bar12_cellstates_over_time.csv", "w+") as w:
    
    
    w.write(','.join(['interval_start'] + all_cell_states) + '\n' )

    for interval in interval_dict:
        d = interval_dict[interval]
        cell_type_counts = [str(d[key]) for key in d.keys()]
        #total_sum = sum(cell_type_counts)
        #if total_sum > 0:
        #    cell_type_props = [str(n/float(total_sum)) for n in cell_type_counts]
        #else:
        #    cell_type_props = [str(n) for n in cell_type_counts]
        w.write(','.join([str(interval)] + cell_type_counts)+ '\n')
