# %%
from Bio import Phylo
from io import StringIO
import networkx as nx
import pandas as pd
from utilities import *
import matplotlib.pyplot as plt

problin_file = "/n/fs/ragr-research/projects/problin_experiments/Real_biodata/run_kptracer/result_trees/pruned_1461/problin_1461.nwk"
startle_file = "/n/fs/ragr-research/projects/problin_experiments/Real_biodata/run_kptracer/result_trees/pruned_1461/startle_1461.nwk"
casshybrid_file = "/n/fs/ragr-research/projects/problin_experiments/Real_biodata/run_kptracer/result_trees/pruned_1461/casshybrid_1461.nwk"
df_kp_meta = pd.read_csv(f'/n/fs/ragr-data/users/palash/multi-linTracer/kp_data/KPTracer-Data/KPTracer_meta.csv', index_col = 0)
df_character_matrix_Fam_1 = pd.read_csv('/n/fs/ragr-data/users/palash/multi-linTracer/kp_data/KPTracer-Data/trees/3724_NT_All_character_matrix.txt',
                                        index_col = 0, sep='\t', dtype=str)
df_character_matrix_Fam_1 = df_character_matrix_Fam_1.replace('-', '-1')

# %%
cell_site_info_1 = df_kp_meta.loc[df_character_matrix_Fam_1.index]['SubTumor']
for cell, site in cell_site_info_1.items():
    if len(site.split('_')) > 3:
        cell_site_info_1[cell] = '_'.join(site.split('_')[:-1])
        
cell_site_info_2 = df_kp_meta.loc[df_character_matrix_Fam_1.index]['SubTumor']
for cell, site in cell_site_info_2.items():
    if len(site.split('_')) > 3: 
        cell_site_info_2[cell] = '_'.join(site.split('_')[-2:])

# %%
def get_brlen(u, v, edge_attr):
    return edge_attr['weight']
    
def computeG(T, cell_site_info, state_list, cost_labeling, presence_labeling, node):
    min_cost = min(cost_labeling[node])
    if node == 'root':
         for state_idx in range(len(state_list)):
                if cost_labeling[node][state_idx] == min_cost:
                    presence_labeling[node][state_idx] = 1
                else:
                    presence_labeling[node][state_idx] = 0
    else:
        
        parent_node = list(T.pred[node])[0]
        
        for state_idx in range(len(state_list)):
            presence_labeling[node][state_idx] = 0
        
        for parent_state_idx in range(len(state_list)):
            if presence_labeling[parent_node][parent_state_idx] == 1:

                min_cost = np.inf
                for child_state_idx, child_state in enumerate(state_list):
                    if child_state_idx == parent_state_idx:
                        curr_cost = cost_labeling[node][child_state_idx]
                    else:
                        curr_cost = cost_labeling[node][child_state_idx] + 1

                    if curr_cost < min_cost:
                        min_cost = curr_cost
        
                for child_state_idx in range(len(state_list)):
                    if child_state_idx == parent_state_idx:
                        curr_cost = cost_labeling[node][child_state_idx]
                    else:
                        curr_cost = cost_labeling[node][child_state_idx] + 1
                        
                    if curr_cost == min_cost:
                        presence_labeling[node][child_state_idx] = 1
                

    for child in T[node]:
        computeG(T, cell_site_info, state_list, cost_labeling, presence_labeling, child)
        
def update_parsimonious_labeling_counts(T, cell_site_info, state_list, cost_labeling, count_labeling, node):
    if is_leaf(T, node):
        for state_idx, state in enumerate(state_list):
            if state == cell_site_info[node]:
                cost_labeling[node][state_idx] = 0
                count_labeling[node][state_idx] = 1
            else:
                cost_labeling[node][state_idx] = np.inf
                count_labeling[node][state_idx] = 0
    else:
        for child in T[node]:
            update_parsimonious_labeling_counts(T, cell_site_info, state_list, cost_labeling, count_labeling, child)
        
        for parent_state_idx, state in enumerate(state_list):
            cost_labeling[node][parent_state_idx] = 0
            count_labeling[node][parent_state_idx] = 1
            for child in T[node]:
                min_cost = np.inf
                for child_state_idx, child_state in enumerate(state_list):
                    if child_state_idx == parent_state_idx:
                        curr_cost = cost_labeling[child][child_state_idx]
                    else:
                        curr_cost = cost_labeling[child][child_state_idx] + 1

                    if curr_cost < min_cost:
                        min_cost = curr_cost
                        min_child_state_idx = child_state_idx

                cost_labeling[node][parent_state_idx] += min_cost

                curr_child_total_count = 0
                for child_state_idx, child_state in enumerate(state_list):
                    if child_state_idx == parent_state_idx:
                        curr_cost = cost_labeling[child][child_state_idx]
                    else:
                        curr_cost = cost_labeling[child][child_state_idx] + 1

                    if curr_cost == min_cost:
                        curr_child_total_count += count_labeling[child][child_state_idx]

                count_labeling[node][parent_state_idx] *= curr_child_total_count

def count_parsimonious_labelings(T, cell_site_info):
    state_list = list(cell_site_info.unique())
    nstates = len(state_list)
    # state_transition_counter = Counter()
    node_cost_labeling = {node:[None]*nstates for node in T.nodes}
    # print(T.nodes)
    # print(node_cost_labeling['root'])
    node_count_labeling = {node:[None]*nstates for node in T.nodes}
    update_parsimonious_labeling_counts(T, cell_site_info, state_list, node_cost_labeling, node_count_labeling, 'root')
    
    return node_cost_labeling, node_count_labeling
    
def count_transitions(input_tree, cell_site_info, throw_out_identical_sites=True):
    num_leaves = 0
    for n in input_tree.nodes:
        if is_leaf(input_tree, n): 
            num_leaves += 1
    
    print(f"input tree has {len(input_tree.nodes)} nodes and {num_leaves} leaves")
    if throw_out_identical_sites:
        input_tree = get_smaller_tree(input_tree, cell_site_info_1)
        print(f"modified tree has {len(input_tree.nodes)} nodes") 
    
    num_leaves = 0
    for n in input_tree.nodes:
        if is_leaf(input_tree, n): 
            num_leaves += 1
    print(f"modified tree has {num_leaves} leaves")
    cost_labeling, count_labeling = count_parsimonious_labelings(input_tree, cell_site_info)
    state_list = list(cell_site_info.unique())
    nstates = len(state_list)
    presence_labeling = {node:[None]*nstates for node in input_tree.nodes}
    computeG(input_tree, cell_site_info, state_list, cost_labeling, presence_labeling, 'root')

    optimal_labeling = {node:'' for node in input_tree.nodes}

    for node in input_tree.nodes:
        if presence_labeling[node][0] == 1:
            optimal_labeling[node] = 0
        else:
            optimal_labeling[node] = np.where(presence_labeling[node])[0][0]

    num_transitions = Counter()
    for edge in input_tree.edges:
        if optimal_labeling[edge[0]] != optimal_labeling[edge[1]]:
            num_transitions[(optimal_labeling[edge[0]], optimal_labeling[edge[1]])] += 1

    return optimal_labeling, presence_labeling, num_transitions, sum(num_transitions.values())

# %%
tree_path = problin_file
if tree_path.startswith('[&R]'):
    handle = StringIO(tree_path)
    phylo_tree = Phylo.read(handle, 'newick')
    net_tree = Phylo.to_networkx(phylo_tree)
else:
    phylo_tree = Phylo.read(tree_path, 'newick')
    net_tree = Phylo.to_networkx(phylo_tree)

# %%
root = list(net_tree.nodes)[0]
new_net_tree = net_tree.copy()
node_renaming_mapping = {}
name_to_node = {}
idx = 0
for node in net_tree.nodes:
    if str(node) == 'Clade':
        node_renaming_mapping[node] = f'clade_{idx}'
        name_to_node[f'clade_{idx}'] = node
        idx = idx + 1
    else:
        node_renaming_mapping[node] = str(node)
        name_to_node[str(node)] = node
node_renaming_mapping[list(net_tree.nodes)[0]] = 'root'

# %%
new_net_tree = nx.relabel_nodes(new_net_tree, node_renaming_mapping)
for node in net_tree.nodes:
    if str(node) == 'Clade':
        node_renaming_mapping[node] = f'clade_{idx}'
        idx = idx + 1
    else:
        node_renaming_mapping[node] = str(node)

name_to_node['root'] = name_to_node['clade_0']

attrs = {}
for new_node in new_net_tree.nodes:
    #print("new_node", new_node)
    node = name_to_node[new_node]
    #print(new_net_tree.edges(new_node))
    for edge in new_net_tree.edges(new_node):
        #print("edge", edge)
        u, v = edge
        weight = net_tree[name_to_node[u]][name_to_node[v]]['weight']
        attrs[(u, v)] = {'weight': weight}

# %%
nx.set_edge_attributes(new_net_tree, attrs)
directed_tree = nx.DiGraph()
directed_tree.add_edges_from(list(nx.bfs_edges(new_net_tree, 'root')))
nx.set_edge_attributes(directed_tree, attrs)

# %%
problin_1461 = directed_tree
mapping = dict()
for i, name in enumerate(cell_site_info_1.unique()): 
    mapping[i] = name

# %%
# get the number of metastases over # lineages

input_tree = problin_1461
# def count_transition_heights(input_tree, use_weights=False): 
transition_heights = dict()
a_optimal_labeling, a_presence_labeling, a_transitions, a_cost = count_transitions(input_tree, cell_site_info_1, False)
for edge in input_tree.edges:
    branch_len = input_tree.edges[edge]['weight']

    from_label = mapping[a_optimal_labeling[edge[0]]].strip()
    to_label = mapping[a_optimal_labeling[edge[1]]].strip()

    if from_label != to_label:
        from_primary = True if from_label == '3724_NT_T1' else False
        to_primary = True if to_label == '3724_NT_T1' else False
    
        if from_primary and to_primary:
            branch_type = "p2p_transition"
        elif from_primary and not to_primary:
            branch_type = "p2n_transition"
        elif not from_primary and not to_primary:
            branch_type = "n2n_transition"
            #print(from_label, to_label)
        elif not from_primary and to_primary:
            branch_type = "n2p_transition"
            # print(branch_type)
        else:
            branch_type = "hm?"
    else:
        branch_type = "not_transition"
    start_branch_height = nx.shortest_path_length(input_tree, source='root', target=edge[0], weight=get_brlen)
    end_branch_height = nx.shortest_path_length(input_tree, source='root', target=edge[1], weight=get_brlen)
    
    transition_heights[edge] = (start_branch_height, end_branch_height, branch_type)
# Out:
# input tree has 2921 nodes and 1461 leaves
# modified tree has 1461 leaves

# %%
transition_heights
# Out:
# {('root', 'clade_1'): (0, 0.19311067051961742, 'not_transition'),
#  ('root', 'clade_7'): (0, 0.005, 'not_transition'),
#  ('clade_1', 'clade_2'): (0.19311067051961742,
#   0.6578658037152288,
#   'not_transition'),
#  ('clade_1', 'L8.CGGAGCTTCGGAAATA-1'): (0.19311067051961742,
#   2.4760264849530227,
#   'not_transition'),
#  ('clade_7', 'clade_8'): (0.005, 0.7928975489609431, 'not_transition'),
#  ('clade_7', 'clade_10'): (0.005, 0.01, 'not_transition'),
#  ('clade_2', 'clade_3'): (0.6578658037152288,
#   1.042211541826986,
#   'not_transition'),
#  ('clade_2', 'L9.CTGCGGAGTAGGCTGA-1'): (0.6578658037152288,
#   2.4760264849530227,
#   'not_transition'),
#  ('clade_8', 'clade_9'): (0.7928975489609431,
#   1.3899931442025095,
#   'not_transition'),
#  ('clade_8', 'L8.TCACGAATCCCATTAT-1'): (0.7928975489609431,
#   2.4760272189148385,
#   'not_transition'),
#  ('clade_10', 'clade_11'): (0.01, 0.1360013610013078, 'not_transition'),
#  ('clade_10', 'clade_815'): (0.01, 0.015, 'not_transition'),
#  ('clade_3', 'L9.GAACATCTCTCTAGGA-1'): (1.042211541826986,
#   2.4760264849530227,
#   'not_transition'),
#  ('clade_3', 'clade_4'): (1.042211541826986,
#   1.9546994171325678,
#   'not_transition'),
#  ('clade_9', 'L8.TCGAGGCGTATAAACG-1'): (1.3899931442025095,
#   2.4760272189148385,
#   'not_transition'),
#  ('clade_9', 'L8.GCTCCTAGTTCGTGAT-1'): (1.3899931442025095,
#   2.4760272189148385,
#   'not_transition'),
#  ('clade_11', 'clade_12'): (0.1360013610013078,
#   0.2631939516703012,
#   'not_transition'),
#  ('clade_11', 'clade_798'): (0.1360013610013078,
#   1.0194231609133657,
#   'not_transition'),
#  ('clade_815', 'clade_816'): (0.015, 0.12817298282909295, 'not_transition'),
#  ('clade_815', 'clade_836'): (0.015, 0.02, 'not_transition'),
#  ('clade_4', 'clade_5'): (1.9546994171325678,
#   1.9597029442847114,
#   'not_transition'),
#  ('clade_4', 'L11.TAGTGGTTCATACGGT-1'): (1.9546994171325678,
#   2.4760264804675463,
#   'p2n_transition'),
#  ('clade_12', 'clade_13'): (0.2631939516703012,
#   0.4647049005596632,
#   'not_transition'),
#  ('clade_12', 'clade_16'): (0.2631939516703012,
#   0.36828580765467445,
#   'not_transition'),
#  ('clade_798', 'clade_799'): (1.0194231609133657,
#   1.024424752000945,
#   'not_transition'),
#  ('clade_798', 'clade_806'): (1.0194231609133657,
#   1.2428564861438747,
#   'not_transition'),
#  ('clade_816', 'clade_817'): (0.12817298282909295,
#   0.4702757224813994,
#   'not_transition'),
#  ('clade_816', 'clade_821'): (0.12817298282909295,
#   0.13600718560650907,
#   'not_transition'),
#  ('clade_836', 'clade_837'): (0.02, 0.025, 'not_transition'),
#  ('clade_836', 'clade_846'): (0.02, 0.09320793714465711, 'not_transition'),
#  ('clade_5', 'clade_6'): (1.9597029442847114,
#   1.9647036055588218,
#   'not_transition'),
#  ('clade_5', 'L8.GTCAAGTGTTCCACAA-1'): (1.9597029442847114,
#   2.4760264804675463,
#   'not_transition'),
#  ('clade_13', 'clade_14'): (0.4647049005596632,
#   0.9427791950492397,
#   'not_transition'),
#  ('clade_13', 'L8.CCGTACTCAGCTGCTG-1'): (0.4647049005596632,
#   2.47602785516832,
#   'not_transition'),
#  ('clade_16', 'clade_17'): (0.36828580765467445,
#   0.4621952985983756,
#   'not_transition'),
#  ('clade_16', 'clade_767'): (0.36828580765467445,
#   0.7123242723420742,
#   'not_transition'),
#  ('clade_799', 'clade_800'): (1.024424752000945,
#   1.7517659794265787,
#   'not_transition'),
#  ('clade_799', 'clade_801'): (1.024424752000945,
#   1.58417920061826,
#   'not_transition'),
#  ('clade_806', 'clade_807'): (1.2428564861438747,
#   1.2478595490874416,
#   'p2n_transition'),
#  ('clade_806', 'clade_814'): (1.2428564861438747,
#   1.4435674437842259,
#   'not_transition'),
#  ('clade_817', 'clade_818'): (0.4702757224813994,
#   1.150436150529829,
#   'p2n_transition'),
#  ('clade_817', 'clade_820'): (0.4702757224813994,
#   1.192784749906862,
#   'not_transition'),
#  ('clade_821', 'clade_822'): (0.13600718560650907,
#   0.41536823363736886,
#   'not_transition'),
#  ('clade_821', 'L8.TTCGGTCGTGATGTCT-1'): (0.13600718560650907,
#   2.4760285425970174,
#   'not_transition'),
#  ('clade_837', 'clade_838'): (0.025, 0.03156203629714415, 'not_transition'),
#  ('clade_837', 'clade_845'): (0.025, 0.3676195061621374, 'not_transition'),
#  ('clade_846', 'clade_847'): (0.09320793714465711,
#   0.09820793714465711,
#   'not_transition'),
#  ('clade_846', 'clade_1458'): (0.09320793714465711,
#   2.465811983877531,
#   'not_transition'),
#  ('clade_6', 'L11.CGAGCACGTACCGAGA-1'): (1.9647036055588218,
#   2.4760264804675463,
#   'p2n_transition'),
#  ('clade_6', 'L8.CAAGAAAGTCGCGGTT-1'): (1.9647036055588218,
#   2.4760264804675463,
#   'not_transition'),
#  ('clade_14', 'clade_15'): (0.9427791950492397,
#   1.2283296103410106,
#   'not_transition'),
#  ('clade_14', 'L10.GTGCATAGTTATCCGA-1'): (0.9427791950492397,
#   2.47602785516832,
#   'not_transition'),
#  ('clade_17', 'clade_18'): (0.4621952985983756,
#   0.6479968981430309,
#   'not_transition'),
#  ('clade_17', 'clade_174'): (0.4621952985983756,
#   0.747396309136499,
#   'not_transition'),
#  ('clade_767', 'clade_768'): (0.7123242723420742,
#   0.9927021575048991,
#   'not_transition'),
#  ('clade_767', 'clade_785'): (0.7123242723420742,
#   1.0443704687613355,
#   'not_transition'),
#  ('clade_800', 'L10.TAGGCATTCAAACAAG-1'): (1.7517659794265787,
#   2.4760278471616814,
#   'not_transition'),
#  ('clade_800', 'L10.TGACGGCAGGGTGTGT-1'): (1.7517659794265787,
#   2.4760278471616814,
#   'not_transition'),
#  ('clade_801', 'clade_802'): (1.58417920061826,
#   1.589181557471897,
#   'not_transition'),
#  ('clade_801', 'clade_803'): (1.58417920061826,
#   2.014563703048423,
#   'not_transition'),
#  ('clade_807', 'L11.GGAACTTAGAGGGATA-1'): (1.2478595490874416,
#   2.476027853298617,
#   'not_transition'),
#  ('clade_807', 'clade_808'): (1.2478595490874416,
#   1.2528611761517465,
#   'not_transition'),
#  ('clade_814', 'L11.ATGTGTGGTGTTCTTT-1'): (1.4435674437842259,
#   2.476027853298617,
#   'p2n_transition'),
#  ('clade_814', 'L9.GGATGTTGTCTCATCC-1'): (1.4435674437842259,
#   2.476027853298617,
#   'not_transition'),
#  ('clade_818', 'clade_819'): (1.150436150529829,
#   1.7908183640718993,
#   'not_transition'),
#  ('clade_818', 'L11.CACACAAAGTTGAGAT-1'): (1.150436150529829,
#   2.476028531203664,
#   'not_transition'),
#  ('clade_820', 'L8.GACGTGCTCGAACGGA-1'): (1.192784749906862,
#   2.4760285351315714,
#   'not_transition'),
#  ('clade_820', 'L9.ATTGGACAGACGCTTT-1'): (1.192784749906862,
#   2.4760285351315714,
#   'not_transition'),
#  ('clade_822', 'clade_823'): (0.41536823363736886,
#   0.42036927094660426,
#   'not_transition'),
#  ('clade_822', 'clade_831'): (0.41536823363736886,
#   0.5257028490188181,
#   'not_transition'),
#  ('clade_838', 'clade_839'): (0.03156203629714415,
#   0.1911710940752626,
#   'not_transition'),
#  ('clade_838', 'L8.AGCTCTCCATGAACCT-1'): (0.03156203629714415,
#   2.476029664193623,
#   'not_transition'),
#  ('clade_845', 'L8.CAAGATCGTGCCTGGT-1'): (0.3676195061621374,
#   2.4760296671443784,
#   'not_transition'),
#  ('clade_845', 'L8.TTCTACAAGCAGCCTC-1'): (0.3676195061621374,
#   2.4760296671443784,
#   'not_transition'),
#  ('clade_847', 'clade_848'): (0.09820793714465711,
#   0.18429551927121635,
#   'not_transition'),
#  ('clade_847', 'clade_864'): (0.09820793714465711,
#   0.10320793714465712,
#   'not_transition'),
#  ('clade_1458', 'clade_1459'): (2.465811983877531,
#   2.47102405788111,
#   'not_transition'),
#  ('clade_1458', 'L8.AGGCCACGTGTTCGAT-1'): (2.465811983877531,
#   2.4760292624608344,
#   'not_transition'),
#  ('clade_15', 'L9.GGGCACTAGTAACCCT-1'): (1.2283296103410106,
#   2.47602785516832,
#   'not_transition'),
#  ('clade_15', 'L9.ACCTTTAGTCAAACTC-1'): (1.2283296103410106,
#   2.47602785516832,
#   'not_transition'),
#  ('clade_18', 'L9.TTTATGCTCCAGTATG-1'): (0.6479968981430309,
#   2.476027871530164,
#   'not_transition'),
#  ('clade_18', 'clade_19'): (0.6479968981430309,
#   0.7556196105352456,
#   'not_transition'),
#  ('clade_174', 'clade_175'): (0.747396309136499,
#   0.9161700861027615,
#   'not_transition'),
#  ('clade_174', 'clade_273'): (0.747396309136499,
#   0.8988818280354804,
#   'p2n_transition'),
#  ('clade_768', 'clade_769'): (0.9927021575048991,
#   0.9977025294911309,
#   'not_transition'),
#  ('clade_768', 'clade_770'): (0.9927021575048991,
#   1.83411825965534,
#   'not_transition'),
#  ('clade_785', 'clade_786'): (1.0443704687613355,
#   1.4947632691623378,
#   'not_transition'),
#  ('clade_785', 'L9.CTCGGAGAGAATGTGT-1'): (1.0443704687613355,
#   2.4760278438457624,
#   'not_transition'),
#  ('clade_802', 'L9.TACCTATTCGCAAGCC-1'): (1.589181557471897,
#   2.476027834724512,
#   'not_transition'),
#  ('clade_802', 'L9.ACGCCAGGTCCGAACC-1'): (1.589181557471897,
#   2.476027834724512,
#   'not_transition'),
#  ('clade_803', 'clade_804'): (2.014563703048423,
#   2.4660163536052924,
#   'not_transition'),
#  ('clade_803', 'L9.TTCTACACACGAAAGC-1'): (2.014563703048423,
#   2.476027832726613,
#   'not_transition'),
#  ('clade_808', 'clade_809'): (1.2528611761517465,
#   1.257863980559732,
#   'not_transition'),
#  ('clade_808', 'clade_813'): (1.2528611761517465,
#   2.035801589303212,
#   'not_transition'),
#  ('clade_819', 'L11.AAGCCGCAGCTAACAA-1'): (1.7908183640718993,
#   2.476028531203664,
#   'not_transition'),
#  ('clade_819', 'L11.TACTCATGTAACGACG-1'): (1.7908183640718993,
#   2.476028531203664,
#   'not_transition'),
#  ('clade_823', 'clade_824'): (0.42036927094660426,
#   1.0084932455651563,
#   'not_transition'),
#  ('clade_823', 'L8.AGATTGCTCTGGCGAC-1'): (0.42036927094660426,
#   2.476028524655875,
#   'not_transition'),
#  ('clade_831', 'clade_832'): (0.5257028490188181,
#   1.575232015586741,
#   'not_transition'),
#  ('clade_831', 'L9.GTTTCTACATACGCCG-1'): (0.5257028490188181,
#   2.476028553817684,
#   'not_transition'),
#  ('clade_839', 'clade_840'): (0.1911710940752626,
#   0.49259105841177364,
#   'not_transition'),
#  ('clade_839', 'clade_841'): (0.1911710940752626,
#   1.9676703847684638,
#   'not_transition'),
#  ('clade_848', 'clade_849'): (0.18429551927121635,
#   0.4852572797588759,
#   'not_transition'),
#  ('clade_848', 'clade_852'): (0.18429551927121635,
#   0.46428179255859464,
#   'not_transition'),
#  ('clade_864', 'L10.GAACATCAGTCCGTAT-1'): (0.10320793714465712,
#   2.476030542778679,
#   'not_transition'),
#  ('clade_864', 'clade_865'): (0.10320793714465712,
#   0.2014731767817834,
#   'not_transition'),
#  ('clade_1459', 'L8.CTCATTAGTTTGTTGG-1'): (2.47102405788111,
#   2.4760292624608344,
#   'not_transition'),
#  ('clade_1459', 'L8.ATGTGTGTCGTGGACC-1'): (2.47102405788111,
#   2.4760292624608344,
#   'not_transition'),
#  ('clade_19', 'clade_20'): (0.7556196105352456,
#   0.8501812389124598,
#   'not_transition'),
#  ('clade_19', 'clade_127'): (0.7556196105352456,
#   0.7606481373142405,
#   'not_transition'),
#  ('clade_175', 'clade_176'): (0.9161700861027615,
#   0.9213573009163494,
#   'not_transition'),
#  ('clade_175', 'clade_269'): (0.9161700861027615,
#   1.5822840796071558,
#   'p2n_transition'),
#  ('clade_273', 'clade_274'): (0.8988818280354804,
#   1.3631523322482924,
#   'not_transition'),
#  ('clade_273', 'clade_277'): (0.8988818280354804,
#   0.9038818280354805,
#   'not_transition'),
#  ('clade_769', 'L9.GTACGTAGTTGCTCCT-1'): (0.9977025294911309,
#   2.4760278542274907,
#   'not_transition'),
#  ('clade_769', 'L9.GAAATGATCTACTATC-1'): (0.9977025294911309,
#   2.4760278542274907,
#   'not_transition'),
#  ('clade_770', 'clade_771'): (1.83411825965534,
#   2.471025413385385,
#   'not_transition'),
#  ('clade_770', 'clade_772'): (1.83411825965534,
#   1.8391207167844876,
#   'not_transition'),
#  ('clade_786', 'L9.ACGATACTCAGATAAG-1'): (1.4947632691623378,
#   2.4760278438457624,
#   'not_transition'),
#  ('clade_786', 'clade_787'): (1.4947632691623378,
#   1.8609495741175082,
#   'not_transition'),
#  ('clade_804', 'clade_805'): (2.4660163536052924,
#   2.4710180310487067,
#   'not_transition'),
#  ('clade_804', 'L9.CCGTGGATCAGAGACG-1'): (2.4660163536052924,
#   2.476027832726613,
#   'not_transition'),
#  ('clade_809', 'clade_810'): (1.257863980559732,
#   1.7242327092949763,
#   'not_transition'),
#  ('clade_809', 'L9.AGTGGGAGTTCCAACA-1'): (1.257863980559732,
#   2.476027836036123,
#   'n2p_transition'),
#  ('clade_813', 'L11.TGACGGCGTGATGATA-1'): (2.035801589303212,
#   2.4760278490504817,
#   'not_transition'),
#  ('clade_813', 'L11.CGCGGTATCCACGAAT-1'): (2.035801589303212,
#   2.4760278490504817,
#   'not_transition'),
#  ('clade_824', 'clade_825'): (1.0084932455651563,
#   1.3383381533824914,
#   'not_transition'),
#  ('clade_824', 'clade_830'): (1.0084932455651563,
#   2.4710277324424608,
#   'not_transition'),
#  ('clade_832', 'clade_833'): (1.575232015586741,
#   1.9391566395522375,
#   'not_transition'),
#  ('clade_832', 'L9.ACCAGTATCTGCGACG-1'): (1.575232015586741,
#   2.476028545796541,
#   'not_transition'),
#  ('clade_840', 'L8.ACACCAACATTCCTGC-1'): (0.49259105841177364,
#   2.4760296641936232,
#   'not_transition'),
#  ('clade_840', 'L8.TCAGGATAGACCTAGG-1'): (0.49259105841177364,
#   2.4760296641936232,
#   'not_transition'),
#  ('clade_841', 'clade_842'): (1.9676703847684638,
#   1.977040180894722,
#   'not_transition'),
#  ('clade_841', 'L9.CTGAAACCATTCTTAC-1'): (1.9676703847684638,
#   2.476029649139053,
#   'not_transition'),
#  ('clade_849', 'clade_850'): (0.4852572797588759,
#   1.0804321948328388,
#   'not_transition'),
#  ('clade_849', 'L8.TACGGATAGGGAACGG-1'): (0.4852572797588759,
#   2.476029877199793,
#   'not_transition'),
#  ('clade_852', 'clade_853'): (0.46428179255859464,
#   0.8901016576473695,
#   'not_transition'),
#  ('clade_852', 'L9.TGAGCATAGAGCTGGT-1'): (0.46428179255859464,
#   2.476029878291849,
#   'not_transition'),
#  ('clade_865', 'clade_866'): (0.2014731767817834,
#   0.8562327222047255,
#   'not_transition'),
#  ('clade_865', 'clade_877'): (0.2014731767817834,
#   0.3009439197128375,
#   'not_transition'),
#  ('clade_20', 'clade_21'): (0.8501812389124598,
#   0.8551812389124598,
#   'not_transition'),
#  ('clade_20', 'clade_123'): (0.8501812389124598,
#   1.7986563687096997,
#   'not_transition'),
#  ('clade_127', 'clade_128'): (0.7606481373142405,
#   1.1333895925887714,
#   'not_transition'),
#  ('clade_127', 'L10.TCGCGAGAGCAGGCTA-1'): (0.7606481373142405,
#   2.4760279101212253,
#   'not_transition'),
#  ('clade_176', 'clade_177'): (0.9213573009163494,
#   0.9263583664957813,
#   'not_transition'),
#  ('clade_176', 'clade_226'): (0.9213573009163494,
#   1.6979618329998876,
#   'not_transition'),
#  ('clade_269', 'clade_270'): (1.5822840796071558,
#   1.5872907391017028,
#   'not_transition'),
#  ('clade_269', 'L11.GCTCCTAGTCTCAACA-1'): (1.5822840796071558,
#   2.4760278707975028,
#   'not_transition'),
#  ('clade_274', 'L11.AAGACCTTCCAGAAGG-1'): (1.3631523322482924,
#   2.476027877704766,
#   'not_transition'),
#  ('clade_274', 'clade_275'): (1.3631523322482924,
#   1.9271393215167598,
#   'not_transition'),
#  ('clade_277', 'clade_278'): (0.9038818280354805,
#   1.6161737435140455,
#   'not_transition'),
#  ('clade_277', 'clade_281'): (0.9038818280354805,
#   0.9088818280354805,
#   'not_transition'),
#  ('clade_771', 'L9.TCAGATGTCAGAGCTT-1'): (2.471025413385385,
#   2.476027850295146,
#   'not_transition'),
#  ('clade_771', 'L9.TCTCATAGTAATTGGA-1'): (2.471025413385385,
#   2.476027850295146,
#   'not_transition'),
#  ('clade_772', 'clade_773'): (1.8391207167844876,
#   1.844252490514794,
#   'not_transition'),
#  ('clade_772', 'clade_783'): (1.8391207167844876,
#   2.159612474590536,
#   'not_transition'),
#  ('clade_787', 'clade_788'): (1.8609495741175082,
#   2.148431700431582,
#   'not_transition'),
#  ('clade_787', 'clade_790'): (1.8609495741175082,
#   1.8659613203157226,
#   'not_transition'),
#  ('clade_805', 'L8.TTTGTCACATCTGGTA-1'): (2.4710180310487067,
#   2.476027832726613,
#   'not_transition'),
#  ('clade_805', 'L9.GTCAAGTGTCATGCAT-1'): (2.4710180310487067,
#   2.476027832726613,
#   'not_transition'),
#  ('clade_810', 'clade_811'): (1.7242327092949763,
#   1.84321099385258,
#   'not_transition'),
#  ('clade_810', 'L11.TGGCCAGAGTACGATA-1'): (1.7242327092949763,
#   2.4760278449382493,
#   'not_transition'),
#  ('clade_825', 'clade_826'): (1.3383381533824914,
#   1.343338770850327,
#   'not_transition'),
#  ('clade_825', 'L8.TGACTAGGTTAGATGA-1'): (1.3383381533824914,
#   2.476028531646388,
#   'not_transition'),
#  ('clade_830', 'L9.CTTACCGGTCTTTCAT-1'): (2.4710277324424608,
#   2.4760285257342414,
#   'not_transition'),
#  ('clade_830', 'L9.GCGCAGTAGTGGGATC-1'): (2.4710277324424608,
#   2.4760285257342414,
#   'not_transition'),
#  ('clade_833', 'clade_834'): (1.9391566395522375,
#   1.9441596661747584,
#   'not_transition'),
#  ('clade_833', 'L9.TGTGTTTCATCCCATC-1'): (1.9391566395522375,
#   2.476028545796541,
#   'not_transition'),
#  ('clade_842', 'clade_843'): (1.977040180894722,
#   2.4710256152135552,
#   'not_transition'),
#  ('clade_842', 'clade_844'): (1.977040180894722,
#   1.9820405857858447,
#   'not_transition'),
#  ('clade_850', 'L8.CGGACACTCTCTGCTG-1'): (1.0804321948328388,
#   2.4760298771997933,
#   'not_transition'),
#  ('clade_850', 'clade_851'): (1.0804321948328388,
#   2.464820984156849,
#   'not_transition'),
#  ('clade_853', 'clade_854'): (0.8901016576473695,
#   0.8951021913139924,
#   'not_transition'),
#  ('clade_853', 'clade_860'): (0.8901016576473695,
#   1.572140224811471,
#   'not_transition'),
#  ('clade_866', 'clade_867'): (0.8562327222047255,
#   0.8655252813015849,
#   'not_transition'),
#  ('clade_866', 'clade_868'): (0.8562327222047255,
#   1.1194484893710996,
#   'not_transition'),
#  ('clade_877', 'clade_878'): (0.3009439197128375,
#   0.4050581399587675,
#   'not_transition'),
#  ('clade_877', 'L8.CTACGTCAGAAACCGC-1'): (0.3009439197128375,
#   2.476030574851131,
#   'not_transition'),
#  ('clade_21', 'clade_22'): (0.8551812389124598,
#   0.8601835120655869,
#   'not_transition'),
#  ('clade_21', 'clade_27'): (0.8551812389124598,
#   0.8601812389124598,
#   'not_transition'),
#  ('clade_123', 'clade_124'): (1.7986563687096997,
#   1.8036671310674286,
#   'not_transition'),
#  ('clade_123', 'clade_126'): (1.7986563687096997,
#   1.803695040537117,
#   'not_transition'),
#  ('clade_128', 'clade_129'): (1.1333895925887714,
#   1.1383957627064876,
#   'not_transition'),
#  ('clade_128', 'L9.GGGACCTTCACTATTC-1'): (1.1333895925887714,
#   2.4760279072727744,
#   'not_transition'),
#  ('clade_177', 'clade_178'): (0.9263583664957813,
#   0.9313592611473309,
#   'not_transition'),
#  ('clade_177', 'clade_218'): (0.9263583664957813,
#   1.205450660035942,
#   'not_transition'),
#  ('clade_226', 'clade_227'): (1.6979618329998876,
#   1.7029911285763204,
#   'not_transition'),
#  ('clade_226', 'L9.GCAGCCAAGCCCAATT-1'): (1.6979618329998876,
#   2.476027851092624,
#   'not_transition'),
#  ('clade_270', 'clade_271'): (1.5872907391017028,
#   1.5922938987746331,
#   'not_transition'),
#  ('clade_270', 'L11.TGAGGGATCACGACTA-1'): (1.5872907391017028,
#   2.476027861866128,
#   'not_transition'),
#  ('clade_275', 'clade_276'): (1.9271393215167598,
#   2.4689260617061843,
#   'n2p_transition'),
#  ('clade_275', 'L11.CGCTATCTCACAAACC-1'): (1.9271393215167598,
#   2.476027877704766,
#   'not_transition'),
#  ('clade_278', 'L11.ATAACGCTCCTTTACA-1'): (1.6161737435140455,
#   2.476028138602037,
#   'not_transition'),
#  ('clade_278', 'clade_279'): (1.6161737435140455,
#   1.6211766271825367,
#   'not_transition'),
#  ('clade_281', 'clade_282'): (0.9088818280354805,
#   1.3368808735541826,
#   'not_transition'),
#  ('clade_281', 'clade_292'): (0.9088818280354805,
#   0.9138818280354805,
#   'not_transition'),
#  ('clade_773', 'clade_774'): (1.844252490514794,
#   1.8494678918906033,
#   'not_transition'),
#  ('clade_773', 'clade_782'): (1.844252490514794,
#   2.4710255449403316,
#   'not_transition'),
#  ('clade_783', 'clade_784'): (2.159612474590536,
#   2.471021365742829,
#   'not_transition'),
#  ('clade_783', 'L9.GCTTGAATCTGTCTAT-1'): (2.159612474590536,
#   2.4760278557499444,
#   'not_transition'),
#  ('clade_788', 'L9.TGAGCCGAGCGACGTA-1'): (2.148431700431582,
#   2.476027843845763,
#   'not_transition'),
#  ('clade_788', 'clade_789'): (2.148431700431582,
#   2.471027702683471,
#   'not_transition'),
#  ('clade_790', 'clade_791'): (1.8659613203157226,
#   2.4710257466220003,
#   'not_transition'),
#  ('clade_790', 'clade_792'): (1.8659613203157226,
#   1.87097315401169,
#   'not_transition'),
#  ('clade_811', 'clade_812'): (1.84321099385258,
#   1.8485459388376726,
#   'not_transition'),
#  ('clade_811', 'L11.ACGGCCAAGGAATGGA-1'): (1.84321099385258,
#   2.4760278449382493,
#   'not_transition'),
#  ('clade_826', 'clade_827'): (1.343338770850327,
#   1.6098506177060772,
#   'not_transition'),
#  ('clade_826', 'clade_829'): (1.343338770850327,
#   2.094444889930007,
#   'not_transition'),
#  ('clade_834', 'L9.CATCCACTCGACGGAA-1'): (1.9441596661747584,
#   2.476028545796541,
#   'not_transition'),
#  ('clade_834', 'clade_835'): (1.9441596661747584,
#   2.4685126881559656,
#   'not_transition'),
#  ('clade_843', 'L9.TACGGTATCCTGTACC-1'): (2.4710256152135552,
#   2.476029649139053,
#   'not_transition'),
#  ('clade_843', 'L9.GGCCGATGTCGGGTCT-1'): (2.4710256152135552,
#   2.476029649139053,
#   'not_transition'),
#  ('clade_844', 'L9.AACGTTGAGGTCGGAT-1'): (1.9820405857858447,
#   2.476029649139053,
#   'not_transition'),
#  ('clade_844', 'L9.TCTTTCCGTGCTAGCC-1'): (1.9820405857858447,
#   2.476029649139053,
#   'not_transition'),
#  ('clade_851', 'L9.GCATGCGAGGCCGAAT-1'): (2.464820984156849,
#   2.476029877199793,
#   'not_transition'),
#  ('clade_851', 'L9.TGCACCTAGAAGGGTA-1'): (2.464820984156849,
#   2.476029877199793,
#   'not_transition'),
#  ('clade_854', 'clade_855'): (0.8951021913139924,
#   1.7265980831789656,
#   'not_transition'),
#  ('clade_854', 'clade_859'): (0.8951021913139924,
#   1.7379148135744062,
#   'not_transition'),
#  ('clade_860', 'L9.AGCCTAAAGATCTGCT-1'): (1.572140224811471,
#   2.476029886366448,
#   'not_transition'),
#  ('clade_860', 'clade_861'): (1.572140224811471,
#   1.5771443003318757,
#   'not_transition'),
#  ('clade_867', 'L11.TCTATTGTCTCGGACG-1'): (0.8655252813015849,
#   2.4760305564627547,
#   'p2n_transition'),
#  ('clade_867', 'L8.TCCACACCAAGGACTG-1'): (0.8655252813015849,
#   2.4760305564627547,
#   'not_transition'),
#  ('clade_868', 'clade_869'): (1.1194484893710996,
#   1.4307227439642494,
#   'not_transition'),
#  ('clade_868', 'L11.ACCGTAAAGGCTCTTA-1'): (1.1194484893710996,
#   2.4760305545514774,
#   'p2n_transition'),
#  ('clade_878', 'clade_879'): (0.4050581399587675,
#   0.6289510723502647,
#   'not_transition'),
#  ('clade_878', 'clade_891'): (0.4050581399587675,
#   0.5200655830683083,
#   'not_transition'),
#  ('clade_22', 'clade_23'): (0.8601835120655869,
#   2.2719377810390777,
#   'not_transition'),
#  ('clade_22', 'clade_25'): (0.8601835120655869,
#   0.8651863278797555,
#   'not_transition'),
#  ('clade_27', 'clade_28'): (0.8601812389124598,
#   0.8651812389124598,
#   'not_transition'),
#  ('clade_27', 'L9.TTTATGCGTCGAGATG-1'): (0.8601812389124598,
#   2.4760290436751307,
#   'not_transition'),
#  ('clade_124', 'clade_125'): (1.8036671310674286,
#   1.808685467392351,
#   'not_transition'),
#  ('clade_124', 'L9.GCATGATGTCGCATAT-1'): (1.8036671310674286,
#   2.476027921677658,
#   'not_transition'),
#  ('clade_126', 'L10.TCATTTGTCGGTCCGA-1'): (1.803695040537117,
#   2.4760279226962396,
#   'not_transition'),
#  ('clade_126', 'L9.TTTCCTCTCACATACG-1'): (1.803695040537117,
#   2.4760279226962396,
#   'not_transition'),
#  ('clade_129', 'clade_130'): (1.1383957627064876,
#   2.4703047875955395,
#   'not_transition'),
#  ('clade_129', 'clade_131'): (1.1383957627064876,
#   1.1433980482617982,
#   'not_transition'),
#  ('clade_178', 'clade_179'): (0.9313592611473309,
#   0.936360370359734,
#   'not_transition'),
#  ('clade_178', 'clade_201'): (0.9313592611473309,
#   1.1846780771888707,
#   'not_transition'),
#  ('clade_218', 'clade_219'): (1.205450660035942,
#   1.5646207113006914,
#   'not_transition'),
#  ('clade_218', 'L10.CTCTACGCACAGGCCT-1'): (1.205450660035942,
#   2.476027857093743,
#   'not_transition'),
#  ('clade_227', 'clade_228'): (1.7029911285763204,
#   1.707995784576907,
#   'not_transition'),
#  ('clade_227', 'clade_267'): (1.7029911285763204,
#   2.2168326872238535,
#   'not_transition'),
#  ('clade_271', 'clade_272'): (1.5922938987746331,
#   2.4710173796803616,
#   'not_transition'),
#  ('clade_271', 'L11.CCTTTCTCAAACGCGA-1'): (1.5922938987746331,
#   2.476027861866128,
#   'not_transition'),
#  ('clade_276', 'L9.GACCTGGGTCAGAAGC-1'): (2.4689260617061843,
#   2.4760278777047655,
#   'not_transition'),
#  ('clade_276', 'L9.GCTGCGATCGCGCCAA-1'): (2.4689260617061843,
#   2.4760278777047655,
#   'not_transition'),
#  ('clade_279', 'clade_280'): (1.6211766271825367,
#   2.471018473929531,
#   'not_transition'),
#  ('clade_279', 'L11.GAAATGATCTCAAGTG-1'): (1.6211766271825367,
#   2.476028138602037,
#   'not_transition'),
#  ('clade_282', 'clade_283'): (1.3368808735541826,
#   1.3418818897722593,
#   'not_transition'),
#  ('clade_282', 'clade_289'): (1.3368808735541826,
#   1.3418830676364524,
#   'not_transition'),
#  ('clade_292', 'clade_293'): (0.9138818280354805,
#   0.9188840814724566,
#   'not_transition'),
#  ('clade_292', 'clade_299'): (0.9138818280354805,
#   0.9188818280354805,
#   'not_transition'),
#  ('clade_774', 'clade_775'): (1.8494678918906033,
#   1.8967314214922402,
#   'not_transition'),
#  ('clade_774', 'clade_781'): (1.8494678918906033,
#   2.471025641091113,
#   'not_transition'),
#  ('clade_782', 'L9.CACTCCACACCATCCT-1'): (2.4710255449403316,
#   2.4760278467338512,
#   'not_transition'),
#  ('clade_782', 'L9.TGCGGGTAGATATGGT-1'): (2.4710255449403316,
#   2.4760278467338512,
#   'not_transition'),
#  ('clade_784', 'L10.GGACAGAAGATACACA-1'): (2.471021365742829,
#   2.4760278557499444,
#   'not_transition'),
#  ('clade_784', 'L9.TCAGCAACATCCCATC-1'): (2.471021365742829,
#   2.4760278557499444,
#   'not_transition'),
#  ('clade_789', 'L9.CTCGAGGCATGCCTAA-1'): (2.471027702683471,
#   2.476027843845763,
#   'not_transition'),
#  ('clade_789', 'L9.GCACTCTCACTCTGTC-1'): (2.471027702683471,
#   2.476027843845763,
#   'not_transition'),
#  ('clade_791', 'L9.CATTCGCTCATAGCAC-1'): (2.4710257466220003,
#   2.476027835143908,
#   'not_transition'),
#  ('clade_791', 'L9.CGGTTAATCAGTTGAC-1'): (2.4710257466220003,
#   2.476027835143908,
#   'not_transition'),
#  ('clade_792', 'clade_793'): (1.87097315401169,
#   1.8759885198913135,
#   'not_transition'),
#  ('clade_792', 'L9.ACTTGTTGTACCATCA-1'): (1.87097315401169,
#   2.476027827297477,
#   'not_transition'),
#  ('clade_812', 'L11.GTAGGCCGTAAGAGGA-1'): (1.8485459388376726,
#   2.4760278449382493,
#   'not_transition'),
#  ('clade_812', 'L11.GGTGCGTCAAAGGAAG-1'): (1.8485459388376726,
#   2.4760278449382493,
#   'not_transition'),
#  ('clade_827', 'clade_828'): (1.6098506177060772,
#   1.6148517890173242,
#   'not_transition'),
#  ('clade_827', 'L9.CTCAGAAAGAGTAATC-1'): (1.6098506177060772,
#   2.4760285344322646,
#   'not_transition'),
#  ('clade_829', 'L9.GCCAAATGTGAGCGAT-1'): (2.094444889930007,
#   2.476028525611864,
#   'not_transition'),
#  ('clade_829', 'L9.CGTAGCGGTAGCTAAA-1'): (2.094444889930007,
#   2.476028525611864,
#   'not_transition'),
#  ('clade_835', 'L9.TCTTCGGTCGGTCTAA-1'): (2.4685126881559656,
#   2.476028545796541,
#   'not_transition'),
#  ('clade_835', 'L9.TCCCGATTCACCGTAA-1'): (2.4685126881559656,
#   2.476028545796541,
#   'not_transition'),
#  ('clade_855', 'L9.TTGGCAATCTCGATGA-1'): (1.7265980831789656,
#   2.4760298798412883,
#   'not_transition'),
#  ('clade_855', 'clade_856'): (1.7265980831789656,
#   1.7316044060358033,
#   'not_transition'),
#  ('clade_859', 'L9.TACGGGCAGAGCTGGT-1'): (1.7379148135744062,
#   2.4760298798412883,
#   'not_transition'),
#  ('clade_859', 'L8.TGCGTGGAGAAACGAG-1'): (1.7379148135744062,
#   2.4760298798412883,
#   'not_transition'),
#  ('clade_861', 'clade_862'): (1.5771443003318757,
#   1.5821536763992778,
#   'not_transition'),
#  ('clade_861', 'L9.CTCGAAAAGATCCCAT-1'): (1.5771443003318757,
#   2.4760298866969523,
#   'not_transition'),
#  ('clade_869', 'clade_870'): (1.4307227439642494,
#   1.4357275261624394,
#   'not_transition'),
#  ('clade_869', 'clade_874'): (1.4307227439642494,
#   1.721527754152529,
#   'not_transition'),
#  ('clade_879', 'clade_880'): (0.6289510723502647,
#   0.6339519195675708,
#   'not_transition'),
#  ('clade_879', 'clade_890'): (0.6289510723502647,
#   0.7736265250713514,
#   'not_transition'),
#  ('clade_891', 'clade_892'): (0.5200655830683083,
#   0.6431193102983793,
#   'not_transition'),
#  ('clade_891', 'clade_1419'): (0.5200655830683083,
#   0.5250658482407571,
#   'not_transition'),
#  ('clade_23', 'L10.TGCCCATGTAGCGCTC-1'): (2.2719377810390777,
#   2.476028454036487,
#   'not_transition'),
#  ('clade_23', 'clade_24'): (2.2719377810390777,
#   2.27695259618669,
#   'not_transition'),
#  ('clade_25', 'clade_26'): (0.8651863278797555,
#   2.4689583931441517,
#   'not_transition'),
#  ('clade_25', 'L10.CACAGTAAGATGGCGT-1'): (0.8651863278797555,
#   2.4760284559425867,
#   'not_transition'),
#  ('clade_28', 'clade_29'): (0.8651812389124598,
#   0.8701812389124598,
#   'not_transition'),
#  ('clade_28', 'L9.GGGATGAGTCTAGTGT-1'): (0.8651812389124598,
#   2.4760295689869443,
#   'not_transition'),
#  ('clade_125', 'L10.TCAGGTAGTACTTCTT-1'): (1.808685467392351,
#   2.476027921677658,
#   'not_transition'),
#  ('clade_125', 'L10.CCACCTACAATGGACG-1'): (1.808685467392351,
#   2.476027921677658,
#   'not_transition'),
#  ('clade_130', 'L10.CGCTTCACATTAACCG-1'): (2.4703047875955395,
#   2.476027907272775,
#   'not_transition'),
#  ('clade_130', 'L10.TACCTTAGTCTAGTCA-1'): (2.4703047875955395,
#   2.476027907272775,
#   'not_transition'),
#  ('clade_131', 'clade_132'): (1.1433980482617982,
#   1.5274703479579783,
#   'not_transition'),
#  ('clade_131', 'clade_133'): (1.1433980482617982,
#   1.1484078853274449,
#   'not_transition'),
#  ('clade_179', 'clade_180'): (0.936360370359734,
#   0.9413637954330801,
#   'not_transition'),
#  ('clade_179', 'clade_195'): (0.936360370359734,
#   1.1287764731645311,
#   'not_transition'),
#  ('clade_201', 'clade_202'): (1.1846780771888707,
#   1.5065203631709654,
#   'not_transition'),
#  ('clade_201', 'L9.AACACGTTCACCACCT-1'): (1.1846780771888707,
#   2.4760278634231927,
#   'not_transition'),
#  ('clade_219', 'clade_220'): (1.5646207113006914,
#   1.5696249372684523,
#   'not_transition'),
#  ('clade_219', 'clade_224'): (1.5646207113006914,
#   1.912644134203468,
#   'not_transition'),
#  ('clade_228', 'clade_229'): (1.707995784576907,
#   1.7130043125983156,
#   'not_transition'),
#  ('clade_228', 'clade_230'): (1.707995784576907,
#   1.712996145356553,
#   'not_transition'),
#  ('clade_267', 'clade_268'): (2.2168326872238535,
#   2.221833824687448,
#   'not_transition'),
#  ('clade_267', 'L9.TGCGTGGGTAGTAGTA-1'): (2.2168326872238535,
#   2.4760278422184987,
#   'not_transition'),
#  ('clade_272', 'L11.GGCTCGACAAGAAAGG-1'): (2.4710173796803616,
#   2.4760278618661284,
#   'not_transition'),
#  ('clade_272', 'L9.GCTTGAAGTTGGACCC-1'): (2.4710173796803616,
#   2.4760278618661284,
#   'n2p_transition'),
#  ('clade_280', 'L11.CGGGTCAGTCTTCTCG-1'): (2.471018473929531,
#   2.4760281386020373,
#   'not_transition'),
#  ('clade_280', 'L9.CACACTCCAAGTTCTG-1'): (2.471018473929531,
#   2.4760281386020373,
#   'n2p_transition'),
#  ('clade_283', 'clade_284'): (1.3418818897722593,
#   1.3468824430790631,
#   'not_transition'),
#  ('clade_283', 'L11.CGTGTCTAGTGACTCT-1'): (1.3418818897722593,
#   2.476028579961752,
#   'not_transition'),
#  ('clade_289', 'clade_290'): (1.3418830676364524,
#   2.4710212434482726,
#   'not_transition'),
#  ('clade_289', 'clade_291'): (1.3418830676364524,
#   1.921582694749603,
#   'not_transition'),
#  ('clade_293', 'clade_294'): (0.9188840814724566,
#   1.3746463353599547,
#   'not_transition'),
#  ('clade_293', 'clade_297'): (0.9188840814724566,
#   1.6217592318716436,
#   'not_transition'),
#  ('clade_299', 'clade_300'): (0.9188818280354805,
#   0.9238818280354805,
#   'not_transition'),
#  ('clade_299', 'clade_762'): (0.9188818280354805,
#   0.9245801934417895,
#   'not_transition'),
#  ('clade_775', 'clade_776'): (1.8967314214922402,
#   1.9017469507623146,
#   'not_transition'),
#  ('clade_775', 'clade_780'): (1.8967314214922402,
#   2.128695100995082,
#   'not_transition'),
#  ('clade_781', 'L9.TCACAAGAGGGAACGG-1'): (2.471025641091113,
#   2.476027846898815,
#   'not_transition'),
#  ('clade_781', 'L9.CGTTCTGGTTTGTTTC-1'): (2.471025641091113,
#   2.476027846898815,
#   'not_transition'),
#  ('clade_793', 'clade_794'): (1.8759885198913135,
#   1.8810122585791285,
#   'not_transition'),
#  ('clade_793', 'L9.CGCTGGACAGGTGCCT-1'): (1.8759885198913135,
#   2.4760278272408254,
#   'not_transition'),
#  ('clade_828', 'L9.CACACAATCTCGCTTG-1'): (1.6148517890173242,
#   2.4760285344322646,
#   'not_transition'),
#  ('clade_828', 'L8.GCAGCCAAGTCTCAAC-1'): (1.6148517890173242,
#   2.4760285344322646,
#   'not_transition'),
#  ('clade_856', 'clade_857'): (1.7316044060358033,
#   2.4660165697720577,
#   'not_transition'),
#  ('clade_856', 'L9.CATGGCGAGTGACTCT-1'): (1.7316044060358033,
#   2.476029877488925,
#   'not_transition'),
#  ('clade_862', 'clade_863'): (1.5821536763992778,
#   2.4634901871078405,
#   'not_transition'),
#  ('clade_862', 'L9.TCTATTGAGACTGTAA-1'): (1.5821536763992778,
#   2.4760298866969523,
#   'not_transition'),
#  ('clade_870', 'clade_871'): (1.4357275261624394,
#   1.4409745440611543,
#   'not_transition'),
#  ('clade_870', 'L9.GGCGACTTCTGCGGCA-1'): (1.4357275261624394,
#   2.4760305636156508,
#   'not_transition'),
#  ('clade_874', 'clade_875'): (1.721527754152529,
#   2.207746000107135,
#   'not_transition'),
#  ('clade_874', 'L9.TTAGGACGTAGAAAGG-1'): (1.721527754152529,
#   2.4760305647610763,
#   'not_transition'),
#  ('clade_880', 'clade_881'): (0.6339519195675708,
#   1.126482443852349,
#   'not_transition'),
#  ('clade_880', 'clade_888'): (0.6339519195675708,
#   0.8913470595623999,
#   'p2n_transition'),
#  ('clade_890', 'L9.ATTTCTGAGGCAGTCA-1'): (0.7736265250713514,
#   2.476030585476738,
#   'not_transition'),
#  ('clade_890', 'L11.CTAATGGAGAAGATTC-1'): (0.7736265250713514,
#   2.476030585476738,
#   'p2n_transition'),
#  ('clade_892', 'clade_893'): (0.6431193102983793,
#   0.6481236512110233,
#   'not_transition'),
#  ('clade_892', 'clade_1349'): (0.6431193102983793,
#   0.753536014098606,
#   'not_transition'),
#  ('clade_1419', 'clade_1420'): (0.5250658482407571,
#   1.2038274694714566,
#   'not_transition'),
#  ('clade_1419', 'clade_1453'): (0.5250658482407571,
#   0.5300658482407571,
#   'not_transition'),
#  ('clade_24', 'L10.ATTGGTGGTTCGCTAA-1'): (2.27695259618669,
#   2.4760284540364874,
#   'not_transition'),
#  ('clade_24', 'L10.CATCCACAGAAACGAG-1'): (2.27695259618669,
#   2.4760284540364874,
#   'not_transition'),
#  ('clade_26', 'L10.TGATTTCGTCGCTTCT-1'): (2.4689583931441517,
#   2.4760284559425867,
#   'not_transition'),
#  ('clade_26', 'L10.GGGCACTTCTTACCTA-1'): (2.4689583931441517,
#   2.4760284559425867,
#   'not_transition'),
#  ('clade_29', 'clade_30'): (0.8701812389124598,
#   0.8751812389124598,
#   'not_transition'),
#  ('clade_29', 'clade_121'): (0.8701812389124598,
#   2.235576590131977,
#   'not_transition'),
#  ('clade_132', 'L10.GACCAATCAACTTGAC-1'): (1.5274703479579783,
#   2.476027903708328,
#   'not_transition'),
#  ('clade_132', 'L10.TACGGGCTCAGAGACG-1'): (1.5274703479579783,
#   2.476027903708328,
#   'not_transition'),
#  ('clade_133', 'clade_134'): (1.1484078853274449,
#   2.4703552338375996,
#   'not_transition'),
#  ('clade_133', 'clade_135'): (1.1484078853274449,
#   1.1534108410671051,
#   'not_transition'),
#  ('clade_180', 'clade_181'): (0.9413637954330801,
#   1.3097872827378234,
#   'not_transition'),
#  ('clade_180', 'clade_190'): (0.9413637954330801,
#   1.529394809885505,
#   'not_transition'),
#  ('clade_195', 'clade_196'): (1.1287764731645311,
#   1.7338528318448299,
#   'not_transition'),
#  ('clade_195', 'clade_199'): (1.1287764731645311,
#   1.6446273657942236,
#   'not_transition'),
#  ('clade_202', 'clade_203'): (1.5065203631709654,
#   1.9939820376536308,
#   'not_transition'),
#  ('clade_202', 'clade_205'): (1.5065203631709654,
#   1.5115216380612055,
#   'not_transition'),
#  ('clade_220', 'clade_221'): (1.5696249372684523,
#   1.5746272301157538,
#   'not_transition'),
#  ('clade_220', 'L9.TTCTCCTGTATGCTTG-1'): (1.5696249372684523,
#   2.476027859728841,
#   'not_transition'),
#  ('clade_224', 'clade_225'): (1.912644134203468,
#   1.9176477504881826,
#   'not_transition'),
#  ('clade_224', 'L9.CACACAAAGAAGGTTT-1'): (1.912644134203468,
#   2.476027868059106,
#   'not_transition'),
#  ('clade_229', 'L9.TACAGTGAGCAGCGTA-1'): (1.7130043125983156,
#   2.4760278468030066,
#   'not_transition'),
#  ('clade_229', 'L9.GGGTTGCGTCCAGTTA-1'): (1.7130043125983156,
#   2.4760278468030066,
#   'not_transition'),
#  ('clade_230', 'clade_231'): (1.712996145356553,
#   1.7179973398678023,
#   'not_transition'),
#  ('clade_230', 'clade_265'): (1.712996145356553,
#   1.973646328276556,
#   'not_transition'),
#  ('clade_268', 'L9.AACGTTGCATATGCTG-1'): (2.221833824687448,
#   2.4760278422184987,
#   'not_transition'),
#  ('clade_268', 'L9.CGTCCATTCCTGCAGG-1'): (2.221833824687448,
#   2.4760278422184987,
#   'not_transition'),
#  ('clade_284', 'clade_285'): (1.3468824430790631,
#   1.660658188771788,
#   'not_transition'),
#  ('clade_284', 'L11.GGTATTGCACGCCAGT-1'): (1.3468824430790631,
#   2.476028579572206,
#   'not_transition'),
#  ('clade_290', 'L11.TAGTGGTCAGTATAAG-1'): (2.4710212434482726,
#   2.4760285805623106,
#   'not_transition'),
#  ('clade_290', 'L9.CCTACACCACCCTATC-1'): (2.4710212434482726,
#   2.4760285805623106,
#   'n2p_transition'),
#  ('clade_291', 'L11.AACTCCCTCAGCGACC-1'): (1.921582694749603,
#   2.4760285805623106,
#   'not_transition'),
#  ('clade_291', 'L11.TAAACCGTCCAAGTAC-1'): (1.921582694749603,
#   2.4760285805623106,
#   'not_transition'),
#  ('clade_294', 'L11.GGAGCAAAGTTACCCA-1'): (1.3746463353599547,
#   2.4760290430271557,
#   'not_transition'),
#  ('clade_294', 'clade_295'): (1.3746463353599547,
#   1.9329713443655216,
#   'not_transition'),
#  ('clade_297', 'clade_298'): (1.6217592318716436,
#   1.6267621656920377,
#   'not_transition'),
#  ('clade_297', 'L11.CCTCAGTTCCCAAGTA-1'): (1.6217592318716436,
#   2.476029036056147,
#   'not_transition'),
#  ('clade_300', 'clade_301'): (0.9238818280354805,
#   0.9288818280354805,
#   'not_transition'),
#  ('clade_300', 'clade_751'): (0.9238818280354805,
#   1.058131122288202,
#   'not_transition'),
#  ('clade_762', 'clade_763'): (0.9245801934417895,
#   1.9385340685434205,
#   'not_transition'),
#  ('clade_762', 'clade_765'): (0.9245801934417895,
#   1.9384433180707648,
#   'not_transition'),
#  ('clade_776', 'clade_777'): (1.9017469507623146,
#   1.9067830241102228,
#   'not_transition'),
#  ('clade_776', 'L9.GGCTGGTCACTTGGAT-1'): (1.9017469507623146,
#   2.476027846408722,
#   'not_transition'),
#  ('clade_780', 'L9.TGGCTGGGTACCCAAT-1'): (2.128695100995082,
#   2.476027843931878,
#   'not_transition'),
#  ('clade_780', 'L9.TCAGATGAGTGTACGG-1'): (2.128695100995082,
#   2.476027843931878,
#   'not_transition'),
#  ('clade_794', 'clade_795'): (1.8810122585791285,
#   1.886069496321669,
#   'not_transition'),
#  ('clade_794', 'L9.ACGTCAAAGTTCGCAT-1'): (1.8810122585791285,
#   2.4760278258883788,
#   'not_transition'),
#  ('clade_857', 'clade_858'): (2.4660165697720577,
#   2.4710215663437722,
#   'not_transition'),
#  ('clade_857', 'L9.TACGGTAAGATCTGAA-1'): (2.4660165697720577,
#   2.476029877488925,
#   'not_transition'),
#  ('clade_863', 'L9.CTGAAGTGTTCCACAA-1'): (2.4634901871078405,
#   2.4760298866969523,
#   'not_transition'),
#  ('clade_863', 'L9.TGTATTCGTTAAGGGC-1'): (2.4634901871078405,
#   2.4760298866969523,
#   'not_transition'),
#  ('clade_871', 'clade_872'): (1.4409745440611543,
#   1.4459757354409195,
#   'not_transition'),
#  ('clade_871', 'L9.TCCACACTCTCTAAGG-1'): (1.4409745440611543,
#   2.476030556390327,
#   'not_transition'),
#  ('clade_875', 'clade_876'): (2.207746000107135,
#   2.471026804264813,
#   'not_transition'),
#  ('clade_875', 'L9.GTTTCTAGTCCTCCAT-1'): (2.207746000107135,
#   2.476030564761076,
#   'not_transition'),
#  ('clade_881', 'clade_882'): (1.126482443852349,
#   1.5249177354204069,
#   'not_transition'),
#  ('clade_881', 'L8.CCTACACAGGTGCAAC-1'): (1.126482443852349,
#   2.4760305667977636,
#   'not_transition'),
#  ('clade_888', 'L11.ATCGAGTTCCGTTGTC-1'): (0.8913470595623999,
#   2.476030578087648,
#   'not_transition'),
#  ('clade_888', 'clade_889'): (0.8913470595623999,
#   1.1055351007780723,
#   'not_transition'),
#  ('clade_893', 'clade_894'): (0.6481236512110233,
#   0.6531263920784058,
#   'not_transition'),
#  ('clade_893', 'clade_903'): (0.6481236512110233,
#   0.6531243044585471,
#   'not_transition'),
#  ('clade_1349', 'clade_1350'): (0.753536014098606,
#   0.7585372654528679,
#   'not_transition'),
#  ('clade_1349', 'clade_1356'): (0.753536014098606,
#   0.8794911115318286,
#   'not_transition'),
#  ('clade_1420', 'clade_1421'): (1.2038274694714566,
#   1.2756530784795934,
#   'not_transition'),
#  ('clade_1420', 'clade_1448'): (1.2038274694714566,
#   1.479106678005538,
#   'not_transition'),
#  ('clade_1453', 'clade_1454'): (0.5300658482407571,
#   0.7265486359530818,
#   'not_transition'),
#  ('clade_1453', 'L11.GCATGCGTCCCAAGTA-1'): (0.5300658482407571,
#   2.4760308451937916,
#   'p2n_transition'),
#  ('clade_30', 'clade_31'): (0.8751812389124598,
#   0.8801812389124598,
#   'not_transition'),
#  ('clade_30', 'clade_119'): (0.8751812389124598,
#   1.7320779805723592,
#   'not_transition'),
#  ('clade_121', 'L9.GCCAAATTCTCGAGTA-1'): (2.235576590131977,
#   2.4760300963791932,
#   'not_transition'),
#  ('clade_121', 'clade_122'): (2.235576590131977,
#   2.240590741190537,
#   'not_transition'),
#  ('clade_134', 'L10.CCGGGATAGCTTTGGT-1'): (2.4703552338375996,
#   2.476027894079715,
#   'not_transition'),
#  ('clade_134', 'L10.TAGGCATAGAGTACCG-1'): (2.4703552338375996,
#   2.476027894079715,
#   'not_transition'),
#  ('clade_135', 'clade_136'): (1.1534108410671051,
#   1.1584178783657375,
#   'not_transition'),
#  ('clade_135', 'clade_173'): (1.1534108410671051,
#   2.4547801689990525,
#   'not_transition'),
#  ('clade_181', 'L9.AAAGCAACAGGACGTA-1'): (1.3097872827378234,
#   2.4760278614152496,
#   'not_transition'),
#  ('clade_181', 'clade_182'): (1.3097872827378234,
#   1.8949325390684235,
#   'not_transition'),
#  ('clade_190', 'clade_191'): (1.529394809885505,
#   2.0055229497771943,
#   'not_transition'),
#  ('clade_190', 'clade_194'): (1.529394809885505,
#   2.4710264317161714,
#   'not_transition'),
#  ('clade_196', 'L9.TTCTCAAGTGAAATCA-1'): (1.7338528318448299,
#   2.476027868437498,
#   'not_transition'),
#  ('clade_196', 'clade_197'): (1.7338528318448299,
#   1.7388532397404277,
#   'not_transition'),
#  ('clade_199', 'clade_200'): (1.6446273657942236,
#   1.649628488713254,
#   'not_transition'),
#  ('clade_199', 'L9.CTCGTCAAGGCTAGAC-1'): (1.6446273657942236,
#   2.476027881282177,
#   'not_transition'),
#  ('clade_203', 'L9.AGATTGCAGTTTGCGT-1'): (1.9939820376536308,
#   2.4760278634231927,
#   'not_transition'),
#  ('clade_203', 'clade_204'): (1.9939820376536308,
#   2.4690266479646166,
#   'not_transition'),
#  ('clade_205', 'clade_206'): (1.5115216380612055,
#   1.5165344600376436,
#   'not_transition'),
#  ('clade_205', 'clade_217'): (1.5115216380612055,
#   1.7793809360157204,
#   'not_transition'),
#  ('clade_221', 'L9.GTTTCTAAGCGAAGGG-1'): (1.5746272301157538,
#   2.476027859728841,
#   'not_transition'),
#  ('clade_221', 'clade_222'): (1.5746272301157538,
#   1.5796287194274776,
#   'not_transition'),
#  ('clade_225', 'L9.GACGTTAAGTTGAGTA-1'): (1.9176477504881826,
#   2.476027868059106,
#   'not_transition'),
#  ('clade_225', 'L9.ACCTTTATCGCTTGTC-1'): (1.9176477504881826,
#   2.476027868059106,
#   'not_transition'),
#  ('clade_231', 'clade_232'): (1.7179973398678023,
#   1.9944419282049066,
#   'not_transition'),
#  ('clade_231', 'clade_236'): (1.7179973398678023,
#   1.7230005901769347,
#   'not_transition'),
#  ('clade_265', 'clade_266'): (1.973646328276556,
#   1.9786600286037033,
#   'not_transition'),
#  ('clade_265', 'L9.AGCGTATTCATCTGCC-1'): (1.973646328276556,
#   2.4760278567886775,
#   'not_transition'),
#  ('clade_285', 'clade_286'): (1.660658188771788,
#   1.6656598408163061,
#   'not_transition'),
#  ('clade_285', 'L11.ACGAGCCGTCAAGCGA-1'): (1.660658188771788,
#   2.476028588056577,
#   'not_transition'),
#  ('clade_295', 'clade_296'): (1.9329713443655216,
#   2.468987890561012,
#   'n2p_transition'),
#  ('clade_295', 'L11.GGAATAAAGTTGAGAT-1'): (1.9329713443655216,
#   2.4760290430271557,
#   'not_transition'),
#  ('clade_298', 'L11.ACACCCTTCTAAGCCA-1'): (1.6267621656920377,
#   2.476029036056147,
#   'not_transition'),
#  ('clade_298', 'L11.CTGGTCTCACTTGGAT-1'): (1.6267621656920377,
#   2.476029036056147,
#   'not_transition'),
#  ('clade_301', 'clade_302'): (0.9288818280354805,
#   1.873874282158766,
#   'not_transition'),
#  ('clade_301', 'clade_303'): (0.9288818280354805,
#   0.9338818280354805,
#   'not_transition'),
#  ('clade_751', 'clade_752'): (1.058131122288202,
#   1.8620717812866978,
#   'not_transition'),
#  ('clade_751', 'L11.TCCACACCACCATGTA-1'): (1.058131122288202,
#   2.4760302757927803,
#   'not_transition'),
#  ('clade_763', 'clade_764'): (1.9385340685434205,
#   1.943554932573655,
#   'not_transition'),
#  ('clade_763', 'L11.CTTTGCGCATTAGGCT-1'): (1.9385340685434205,
#   2.4760296001555973,
#   'not_transition'),
#  ('clade_765', 'L11.TCATTTGTCAGCATGT-1'): (1.9384433180707648,
#   2.4760295905923604,
#   'not_transition'),
#  ('clade_765', 'clade_766'): (1.9384433180707648,
#   1.9434651428962306,
#   'not_transition'),
#  ('clade_777', 'L9.CGAATGTAGATGAGAG-1'): (1.9067830241102228,
#   2.476027846408722,
#   'not_transition'),
#  ('clade_777', 'clade_778'): (1.9067830241102228,
#   2.4660249243293304,
#   'not_transition'),
#  ('clade_795', 'clade_796'): (1.886069496321669,
#   2.4660243629618437,
#   'not_transition'),
#  ('clade_795', 'L9.TCAATCTGTGTGACCC-1'): (1.886069496321669,
#   2.4760278258883788,
#   'not_transition'),
#  ('clade_858', 'L9.AGCATACCACTGAAGG-1'): (2.4710215663437722,
#   2.476029877488925,
#   'not_transition'),
#  ('clade_858', 'L9.GTACTCCGTTGTGGCC-1'): (2.4710215663437722,
#   2.476029877488925,
#   'not_transition'),
#  ('clade_872', 'clade_873'): (1.4459757354409195,
#   1.4509790609636672,
#   'not_transition'),
#  ('clade_872', 'L10.TGAAAGAGTCCGCTGA-1'): (1.4459757354409195,
#   2.476030556390327,
#   'not_transition'),
#  ('clade_876', 'L8.TACTTACAGGCAGGTT-1'): (2.471026804264813,
#   2.476030564761076,
#   'not_transition'),
#  ('clade_876', 'L8.CATTATCTCAGCGATT-1'): (2.471026804264813,
#   2.476030564761076,
#   'not_transition'),
#  ('clade_882', 'clade_883'): (1.5249177354204069,
#   1.5299187729467465,
#   'not_transition'),
#  ('clade_882', 'L11.CGAGAAGTCAAACAAG-1'): (1.5249177354204069,
#   2.4760305743725337,
#   'p2n_transition'),
#  ('clade_889', 'L11.CGTCCATCATAGTAAG-1'): (1.1055351007780723,
#   2.476030578087648,
#   'not_transition'),
#  ('clade_889', 'L11.GTATTCTAGCCCAACC-1'): (1.1055351007780723,
#   2.476030578087648,
#   'not_transition'),
#  ('clade_894', 'clade_895'): (0.6531263920784058,
#   1.125065760546304,
#   'not_transition'),
#  ('clade_894', 'clade_901'): (0.6531263920784058,
#   1.3778795244354929,
#   'not_transition'),
#  ('clade_903', 'clade_904'): (0.6531243044585471,
#   0.8241866611541575,
#   'not_transition'),
#  ('clade_903', 'clade_988'): (0.6531243044585471,
#   0.8327949576104513,
#   'not_transition'),
#  ('clade_1350', 'clade_1351'): (0.7585372654528679,
#   1.505913632610346,
#   'not_transition'),
#  ('clade_1350', 'clade_1352'): (0.7585372654528679,
#   1.2647180400769868,
#   'p2n_transition'),
#  ('clade_1356', 'clade_1357'): (0.8794911115318286,
#   0.8844939607345349,
#   'not_transition'),
#  ('clade_1356', 'clade_1358'): (0.8794911115318286,
#   0.8844911115318286,
#   'p2n_transition'),
#  ('clade_1421', 'clade_1422'): (1.2756530784795934,
#   1.2806566812502165,
#   'not_transition'),
#  ('clade_1421', 'clade_1446'): (1.2756530784795934,
#   1.98978052832043,
#   'not_transition'),
#  ('clade_1448', 'clade_1449'): (1.479106678005538,
#   1.4841095462913376,
#   'not_transition'),
#  ('clade_1448', 'clade_1452'): (1.479106678005538,
#   1.7790037259407447,
#   'not_transition'),
#  ('clade_1454', 'clade_1455'): (0.7265486359530818,
#   1.0268699904368506,
#   'not_transition'),
#  ('clade_1454', 'L11.ACATCAGAGCGCTCCA-1'): (0.7265486359530818,
#   2.4760308451937916,
#   'p2n_transition'),
#  ('clade_31', 'clade_32'): (0.8801812389124598,
#   2.469157210590279,
#   'not_transition'),
#  ('clade_31', 'clade_33'): (0.8801812389124598,
#   0.8851812389124598,
#   'not_transition'),
#  ('clade_119', 'clade_120'): (1.7320779805723592,
#   2.1875134198518533,
#   'not_transition'),
#  ('clade_119', 'L10.GGATTACGTTTGACAC-1'): (1.7320779805723592,
#   2.4760306110642247,
#   'not_transition'),
#  ('clade_122', 'L10.TTAACTCTCTCAAGTG-1'): (2.240590741190537,
#   2.4760300963791932,
#   'not_transition'),
#  ('clade_122', 'L9.AAGCCGCGTAGCGATG-1'): (2.240590741190537,
#   2.4760300963791932,
#   'not_transition'),
#  ('clade_136', 'clade_137'): (1.1584178783657375,
#   1.1634294508074738,
#   'not_transition'),
#  ('clade_136', 'L10.CCACTACTCACGATGT-1'): (1.1584178783657375,
#   2.4760278911236933,
#   'not_transition'),
#  ('clade_173', 'L9.TGAGGGACACAACGTT-1'): (2.4547801689990525,
#   2.476027893901615,
#   'not_transition'),
#  ('clade_173', 'L10.CTCACACGTAATAGCA-1'): (2.4547801689990525,
#   2.476027893901615,
#   'not_transition'),
#  ('clade_182', 'L9.TTAGGCAAGGAGTAGA-1'): (1.8949325390684235,
#   2.4760278614152496,
#   'not_transition'),
#  ('clade_182', 'clade_183'): (1.8949325390684235,
#   1.8999363561312037,
#   'not_transition'),
#  ('clade_191', 'clade_192'): (2.0055229497771943,
#   2.0105270299527205,
#   'not_transition'),
#  ('clade_191', 'L9.CGGAGTCGTAATCGTC-1'): (2.0055229497771943,
#   2.4760278482059497,
#   'not_transition'),
#  ('clade_194', 'L9.TGAAAGAGTACCATCA-1'): (2.4710264317161714,
#   2.4760278384683425,
#   'not_transition'),
#  ('clade_194', 'L9.TTTGGTTCAAGGACAC-1'): (2.4710264317161714,
#   2.4760278384683425,
#   'not_transition'),
#  ('clade_197', 'clade_198'): (1.7388532397404277,
#   1.7438552150612636,
#   'not_transition'),
# ...
#   'not_transition'),
#  ('clade_914', 'clade_915'): (1.2611440242522751,
#   1.7450540179095244,
#   'not_transition'),
#  ('clade_914', 'L9.TTCTACATCACGATGT-1'): (1.2611440242522751,
#   2.4760312520128087,
#   'not_transition'),
#  ('clade_917', 'clade_918'): (0.8491895652616135,
#   1.0803198972593517,
#   'not_transition'),
#  ('clade_917', 'clade_926'): (0.8491895652616135,
#   0.8541895652616135,
#   'not_transition'),
#  ('clade_985', 'clade_986'): (1.2846555818855758,
#   1.8978267930957615,
#   'not_transition'),
#  ('clade_985', 'clade_987'): (1.2846555818855758,
#   1.9020646492534534,
#   'not_transition'),
#  ('clade_993', 'L9.TGGCCAGCACGAGAGT-1'): (2.4634413132907254,
#   2.4760306193336534,
#   'not_transition'),
#  ('clade_993', 'L9.GCGAGAAGTACTTAGC-1'): (2.4634413132907254,
#   2.4760306193336534,
#   'not_transition'),
#  ('clade_1001', 'clade_1002'): (0.8577971146718761,
#   1.7090561828200237,
#   'not_transition'),
#  ('clade_1001', 'clade_1003'): (0.8577971146718761,
#   0.8627973139105745,
#   'not_transition'),
#  ('clade_1329', 'L9.TGAAAGACACATGGGA-1'): (1.709161808975548,
#   2.476030636940851,
#   'not_transition'),
#  ('clade_1329', 'L9.CGGAGCTAGCTACCTA-1'): (1.709161808975548,
#   2.476030636940851,
#   'not_transition'),
#  ('clade_1331', 'L9.TTGACTTTCTCTTATG-1'): (1.5363156094428565,
#   2.4760306391701485,
#   'not_transition'),
#  ('clade_1331', 'L11.TGACTAGCATCATCCC-1'): (1.5363156094428565,
#   2.4760306391701485,
#   'p2n_transition'),
#  ('clade_1335', 'clade_1336'): (1.1723608454215773,
#   1.17736256427023,
#   'not_transition'),
#  ('clade_1335', 'L9.TTATGCTGTGAAATCA-1'): (1.1723608454215773,
#   2.4760306546797732,
#   'not_transition'),
#  ('clade_1347', 'L9.GTGTGCGGTTGCGCAC-1'): (1.4202939072122551,
#   2.4760306470607114,
#   'not_transition'),
#  ('clade_1347', 'L9.CGAGCACGTCAAGCGA-1'): (1.4202939072122551,
#   2.4760306470607114,
#   'not_transition'),
#  ('clade_1365', 'L11.TTTACTGAGAGGTTGC-1'): (2.469480113934942,
#   2.4760326428729496,
#   'not_transition'),
#  ('clade_1365', 'L11.CACCACTCAACCGCCA-1'): (2.469480113934942,
#   2.4760326428729496,
#   'not_transition'),
#  ('clade_1366', 'clade_1367'): (0.9094911115318286,
#   0.9144911115318286,
#   'not_transition'),
#  ('clade_1366', 'clade_1416'): (0.9094911115318286,
#   2.4547221247191624,
#   'not_transition'),
#  ('clade_1427', 'L8.ACGATGTAGGATGGTC-1'): (2.0979286037908005,
#   2.4760306054661205,
#   'not_transition'),
#  ('clade_1427', 'L8.GGAACTTAGACAGACC-1'): (2.0979286037908005,
#   2.4760306054661205,
#   'not_transition'),
#  ('clade_1429', 'L11.ACTGAACCAAGAAGAG-1'): (1.8364448614133053,
#   2.476030596966254,
#   'p2n_transition'),
#  ('clade_1429', 'clade_1430'): (1.8364448614133053,
#   1.8417572379481946,
#   'not_transition'),
#  ('clade_1434', 'L11.AGTGAGGTCTTCGAGA-1'): (2.0664166832901354,
#   2.476030596966254,
#   'not_transition'),
#  ('clade_1434', 'clade_1435'): (2.0664166832901354,
#   2.4710238884141735,
#   'not_transition'),
#  ('clade_1441', 'clade_1442'): (2.010765309258256,
#   2.088383009653062,
#   'not_transition'),
#  ('clade_1441', 'clade_1444'): (2.010765309258256,
#   2.015765309258256,
#   'not_transition'),
#  ('clade_1445', 'L9.GGAATAATCTGCCAGG-1'): (2.0107648940499043,
#   2.476030556602929,
#   'not_transition'),
#  ('clade_1445', 'L9.TTGCCGTAGACACTAA-1'): (2.0107648940499043,
#   2.476030556602929,
#   'not_transition'),
#  ('clade_40', 'clade_41'): (0.9101812389124598,
#   0.9151812389124598,
#   'not_transition'),
#  ('clade_40', 'L9.ATCACGAGTCTTTCAT-1'): (0.9101812389124598,
#   2.476033687113532,
#   'not_transition'),
#  ('clade_142', 'clade_143'): (1.8732874071715204,
#   2.4690051563562974,
#   'not_transition'),
#  ('clade_142', 'L10.GCGCAACAGATGCCAG-1'): (1.8732874071715204,
#   2.476027889112165,
#   'not_transition'),
#  ('clade_148', 'clade_149'): (1.188480060818803,
#   1.193640236099072,
#   'not_transition'),
#  ('clade_148', 'clade_168'): (1.188480060818803,
#   1.5027398468064956,
#   'not_transition'),
#  ('clade_188', 'L9.AAGGCAGGTTCCCTTG-1'): (1.9249918887658584,
#   2.4760278548792916,
#   'not_transition'),
#  ('clade_188', 'L9.TTCTTAGCAAATTGCC-1'): (1.9249918887658584,
#   2.4760278548792916,
#   'not_transition'),
#  ('clade_214', 'clade_215'): (1.8485401061491586,
#   1.8537774811880106,
#   'not_transition'),
#  ('clade_214', 'L9.TACTTGTCAGTCGTGC-1'): (1.8485401061491586,
#   2.4760278387921253,
#   'not_transition'),
#  ('clade_245', 'clade_246'): (2.019948910467681,
#   2.4710266601859012,
#   'not_transition'),
#  ('clade_245', 'clade_247'): (2.019948910467681,
#   2.0249635656846583,
#   'not_transition'),
#  ('clade_259', 'clade_260'): (1.9484758445255492,
#   2.0367461700842955,
#   'not_transition'),
#  ('clade_259', 'L9.AGCTCTCCATCAGTCA-1'): (1.9484758445255492,
#   2.476027839488655,
#   'not_transition'),
#  ('clade_314', 'clade_315'): (1.0751720060875172,
#   1.080172006087517,
#   'not_transition'),
#  ('clade_314', 'clade_627'): (1.0751720060875172,
#   1.0801819956589744,
#   'not_transition'),
#  ('clade_628', 'L11.TTAGGCACATGCCTAA-1'): (1.8062436560198956,
#   2.476034380887248,
#   'not_transition'),
#  ('clade_628', 'L11.TGCACCTTCCCGACTT-1'): (1.8062436560198956,
#   2.476034380887248,
#   'not_transition'),
#  ('clade_632', 'L11.ATTGGTGCAGGTGCCT-1'): (1.3237215553811323,
#   2.4760354038880683,
#   'not_transition'),
#  ('clade_632', 'clade_633'): (1.3237215553811323,
#   1.3287218990891507,
#   'not_transition'),
#  ('clade_644', 'clade_645'): (0.9638818280354805,
#   0.9688818280354805,
#   'not_transition'),
#  ('clade_644', 'clade_724'): (0.9638818280354805,
#   1.758954219325565,
#   'not_transition'),
#  ('clade_725', 'clade_726'): (1.0721220300110872,
#   1.2088398546714163,
#   'not_transition'),
#  ('clade_725', 'L11.AATCGGTTCATCTGCC-1'): (1.0721220300110872,
#   2.476036225524636,
#   'not_transition'),
#  ('clade_758', 'clade_759'): (1.892132357409509,
#   1.8971333275613058,
#   'not_transition'),
#  ('clade_758', 'clade_761'): (1.892132357409509,
#   2.4710271722738697,
#   'not_transition'),
#  ('clade_915', 'clade_916'): (1.7450540179095244,
#   1.750061055033242,
#   'not_transition'),
#  ('clade_915', 'L9.ATTCTACAGGACATTA-1'): (1.7450540179095244,
#   2.4760312520128087,
#   'not_transition'),
#  ('clade_918', 'L9.GGATGTTCAAAGCAAT-1'): (1.0803198972593517,
#   2.4760316506971733,
#   'not_transition'),
#  ('clade_918', 'clade_919'): (1.0803198972593517,
#   1.447240635223685,
#   'not_transition'),
#  ('clade_926', 'clade_927'): (0.8541895652616135,
#   0.8591895652616135,
#   'not_transition'),
#  ('clade_926', 'L8.GGGAGATTCTAACGGT-1'): (0.8541895652616135,
#   2.476031806994257,
#   'not_transition'),
#  ('clade_986', 'L9.TTGGCAATCGTCCAGG-1'): (1.8978267930957615,
#   2.476030896787754,
#   'not_transition'),
#  ('clade_986', 'L9.GAAATGACAACCGCCA-1'): (1.8978267930957615,
#   2.476030896787754,
#   'not_transition'),
#  ('clade_987', 'L9.CTTCTCTTCTCTTGAT-1'): (1.9020646492534534,
#   2.476030896787754,
#   'not_transition'),
#  ('clade_987', 'L9.ACGATACTCCACGTGG-1'): (1.9020646492534534,
#   2.476030896787754,
#   'not_transition'),
#  ('clade_1002', 'L9.TCACGAACAAGGACTG-1'): (1.7090561828200237,
#   2.4760306392252387,
#   'not_transition'),
#  ('clade_1002', 'L9.TTGAACGTCAAAGTAG-1'): (1.7090561828200237,
#   2.4760306392252387,
#   'not_transition'),
#  ('clade_1003', 'clade_1004'): (0.8627973139105745,
#   0.8677976590976265,
#   'not_transition'),
#  ('clade_1003', 'L9.TGAGAGGGTAGGCTGA-1'): (0.8627973139105745,
#   2.4760306522133626,
#   'not_transition'),
#  ('clade_1336', 'clade_1337'): (1.17736256427023,
#   1.1823647920901883,
#   'not_transition'),
#  ('clade_1336', 'L8.CTCTGGTAGGGATCTG-1'): (1.17736256427023,
#   2.4760306545221527,
#   'not_transition'),
#  ('clade_1367', 'clade_1368'): (0.9144911115318286,
#   0.9194911115318286,
#   'not_transition'),
#  ('clade_1367', 'L11.TGTATTCAGTGTACCT-1'): (0.9144911115318286,
#   2.4760333068588327,
#   'not_transition'),
#  ('clade_1416', 'clade_1417'): (2.4547221247191624,
#   2.4597692591000513,
#   'not_transition'),
#  ('clade_1416', 'L11.CACTCCAAGCCGTCGT-1'): (2.4547221247191624,
#   2.476033003058766,
#   'not_transition'),
#  ('clade_1430', 'clade_1431'): (1.8417572379481946,
#   1.8470629394057994,
#   'not_transition'),
#  ('clade_1430', 'L8.ATTATCCGTGATGATA-1'): (1.8417572379481946,
#   2.4760305842682726,
#   'not_transition'),
#  ('clade_1435', 'L11.CACATAGGTCCGCTGA-1'): (2.4710238884141735,
#   2.476030596966254,
#   'not_transition'),
#  ('clade_1435', 'L11.TCTTCGGAGTGAAGTT-1'): (2.4710238884141735,
#   2.476030596966254,
#   'not_transition'),
#  ('clade_1442', 'clade_1443'): (2.088383009653062,
#   2.0936475550222315,
#   'not_transition'),
#  ('clade_1442', 'L11.GGACATTGTCCATCCT-1'): (2.088383009653062,
#   2.4760305626522867,
#   'p2n_transition'),
#  ('clade_1444', 'L9.CCATTCGAGTGAACGC-1'): (2.015765309258256,
#   2.4760306601444033,
#   'not_transition'),
#  ('clade_1444', 'L9.AGTAGTCAGCGTCAAG-1'): (2.015765309258256,
#   2.4760306601444033,
#   'not_transition'),
#  ('clade_41', 'clade_42'): (0.9151812389124598,
#   0.9201812389124598,
#   'not_transition'),
#  ('clade_41', 'L9.CCATGTCTCTCTGTCG-1'): (0.9151812389124598,
#   2.4760340592909054,
#   'not_transition'),
#  ('clade_143', 'L10.ACGGCCATCAGTCCCT-1'): (2.4690051563562974,
#   2.476027889112165,
#   'not_transition'),
#  ('clade_143', 'L10.GTTACAGTCGGAAATA-1'): (2.4690051563562974,
#   2.476027889112165,
#   'not_transition'),
#  ('clade_149', 'clade_150'): (1.193640236099072,
#   1.1986461613678687,
#   'not_transition'),
#  ('clade_149', 'L9.GATCGTAAGCCAGGAT-1'): (1.193640236099072,
#   2.476027877710678,
#   'not_transition'),
#  ('clade_168', 'L10.GTACTTTAGACCACGA-1'): (1.5027398468064956,
#   2.4760278892516707,
#   'not_transition'),
#  ('clade_168', 'clade_169'): (1.5027398468064956,
#   1.5077410374476925,
#   'not_transition'),
#  ('clade_215', 'L9.TCATTACGTGGTCCGT-1'): (1.8537774811880106,
#   2.4760278387921253,
#   'not_transition'),
#  ('clade_215', 'L9.GCATGCGGTCATTAGC-1'): (1.8537774811880106,
#   2.4760278387921253,
#   'not_transition'),
#  ('clade_246', 'L9.CTCGTCAAGATAGGAG-1'): (2.4710266601859012,
#   2.4760278243221534,
#   'not_transition'),
#  ('clade_246', 'L9.TTCTCCTAGAGTGAGA-1'): (2.4710266601859012,
#   2.4760278243221534,
#   'not_transition'),
#  ('clade_247', 'clade_248'): (2.0249635656846583,
#   2.0299698885567516,
#   'not_transition'),
#  ('clade_247', 'clade_258'): (2.0249635656846583,
#   2.4710266902866165,
#   'not_transition'),
#  ('clade_260', 'L9.GGTGCGTAGCAGGTCA-1'): (2.0367461700842955,
#   2.476027839488655,
#   'not_transition'),
#  ('clade_260', 'L9.TATCAGGTCTGGTATG-1'): (2.0367461700842955,
#   2.476027839488655,
#   'not_transition'),
#  ('clade_315', 'clade_316'): (1.080172006087517,
#   1.8102834424344936,
#   'n2p_transition'),
#  ('clade_315', 'clade_317'): (1.080172006087517,
#   1.085172006087517,
#   'not_transition'),
#  ('clade_627', 'L11.GTGCGGTGTCTCCATC-1'): (1.0801819956589744,
#   2.4760348273038773,
#   'not_transition'),
#  ('clade_627', 'L11.CTACACCTCGTCTGAA-1'): (1.0801819956589744,
#   2.4760348273038773,
#   'not_transition'),
#  ('clade_633', 'clade_634'): (1.3287218990891507,
#   1.3337223141738612,
#   'not_transition'),
#  ('clade_633', 'L11.CGAACATCATAGGATA-1'): (1.3287218990891507,
#   2.4760354217260696,
#   'not_transition'),
#  ('clade_645', 'clade_646'): (0.9688818280354805,
#   1.0697916903192448,
#   'not_transition'),
#  ('clade_645', 'clade_683'): (0.9688818280354805,
#   0.9738849182346012,
#   'not_transition'),
#  ('clade_724', 'L11.GCATACAAGAAGGACA-1'): (1.758954219325565,
#   2.4760365822033563,
#   'not_transition'),
#  ('clade_724', 'L11.CGATGGCTCACTATTC-1'): (1.758954219325565,
#   2.4760365822033563,
#   'not_transition'),
#  ('clade_726', 'L11.ACGGCCAGTCTTCTCG-1'): (1.2088398546714163,
#   2.476036225524636,
#   'not_transition'),
#  ('clade_726', 'clade_727'): (1.2088398546714163,
#   1.2138398546714162,
#   'not_transition'),
#  ('clade_759', 'clade_760'): (1.8971333275613058,
#   2.4710283943595077,
#   'not_transition'),
#  ('clade_759', 'L11.CACCAGGGTGAGTGAC-1'): (1.8971333275613058,
#   2.4760302667923697,
#   'not_transition'),
#  ('clade_761', 'L11.TTGGAACGTCTGCAAT-1'): (2.4710271722738697,
#   2.476030252734757,
#   'not_transition'),
#  ('clade_761', 'L11.TCTCATATCCCTGACT-1'): (2.4710271722738697,
#   2.476030252734757,
#   'not_transition'),
#  ('clade_916', 'L9.TCCCGATAGCTGCGAA-1'): (1.750061055033242,
#   2.4760312520128087,
#   'not_transition'),
#  ('clade_916', 'L9.TAGACCACATGGGACA-1'): (1.750061055033242,
#   2.4760312520128087,
#   'not_transition'),
#  ('clade_919', 'L9.TATCAGGGTCGGCTCA-1'): (1.447240635223685,
#   2.4760316506971733,
#   'not_transition'),
#  ('clade_919', 'clade_920'): (1.447240635223685,
#   1.4522426605764531,
#   'not_transition'),
#  ('clade_927', 'clade_928'): (0.8591895652616135,
#   1.1977412091773767,
#   'p2n_transition'),
#  ('clade_927', 'clade_933'): (0.8591895652616135,
#   0.8641895652616135,
#   'not_transition'),
#  ('clade_1004', 'clade_1005'): (0.8677976590976265,
#   0.8727978620746314,
#   'not_transition'),
#  ('clade_1004', 'clade_1328'): (0.8677976590976265,
#   1.715187416297682,
#   'not_transition'),
#  ('clade_1337', 'clade_1338'): (1.1823647920901883,
#   1.1873677856352614,
#   'not_transition'),
#  ('clade_1337', 'L8.GGGCACTAGTCCGTAT-1'): (1.1823647920901883,
#   2.4760306524910094,
#   'not_transition'),
#  ('clade_1368', 'clade_1369'): (0.9194911115318286,
#   2.4549384745252913,
#   'not_transition'),
#  ('clade_1368', 'clade_1371'): (0.9194911115318286,
#   0.9244911115318286,
#   'not_transition'),
#  ('clade_1417', 'L11.TTCCCAGCAGATGAGC-1'): (2.4597692591000513,
#   2.476033003058766,
#   'not_transition'),
#  ('clade_1417', 'L11.TTTGGTTCACCGATAT-1'): (2.4597692591000513,
#   2.476033003058766,
#   'not_transition'),
#  ('clade_1431', 'clade_1432'): (1.8470629394057994,
#   2.4609516644546665,
#   'not_transition'),
#  ('clade_1431', 'L8.ACACCAAGTCGTTGTA-1'): (1.8470629394057994,
#   2.4760305836647265,
#   'not_transition'),
#  ('clade_1443', 'L9.CTGAAACTCAAACGGG-1'): (2.0936475550222315,
#   2.4760305626522867,
#   'not_transition'),
#  ('clade_1443', 'L8.TTTATGCCAATGACCT-1'): (2.0936475550222315,
#   2.4760305626522867,
#   'not_transition'),
#  ('clade_42', 'clade_43'): (0.9201812389124598,
#   0.9251812389124598,
#   'not_transition'),
#  ('clade_42', 'L9.CGAACATGTTGCCTCT-1'): (0.9201812389124598,
#   2.4760344184644887,
#   'not_transition'),
#  ('clade_150', 'clade_151'): (1.1986461613678687,
#   1.4132708475750266,
#   'not_transition'),
#  ('clade_150', 'clade_152'): (1.1986461613678687,
#   1.8082488800257634,
#   'not_transition'),
#  ('clade_169', 'clade_170'): (1.5077410374476925,
#   2.3572109974933566,
#   'not_transition'),
#  ('clade_169', 'L10.GAGTCCGAGTTTAGGA-1'): (1.5077410374476925,
#   2.4760278969346072,
#   'not_transition'),
#  ('clade_248', 'clade_249'): (2.0299698885567516,
#   2.0349736154650606,
#   'not_transition'),
#  ('clade_248', 'L9.GTGGGTCAGATCCTGT-1'): (2.0299698885567516,
#   2.476027804719174,
#   'not_transition'),
#  ('clade_258', 'L9.GAAGCAGTCGCTTAGA-1'): (2.4710266902866165,
#   2.4760278041650685,
#   'not_transition'),
#  ('clade_258', 'L9.CTCTGGTAGTCGCCGT-1'): (2.4710266902866165,
#   2.4760278041650685,
#   'not_transition'),
#  ('clade_316', 'L9.GGGTCTGCACCAACCG-1'): (1.8102834424344936,
#   2.476035405367177,
#   'not_transition'),
#  ('clade_316', 'L9.TTGCGTCAGATGTCGG-1'): (1.8102834424344936,
#   2.476035405367177,
#   'not_transition'),
#  ('clade_317', 'clade_318'): (1.085172006087517,
#   1.0901720060875169,
#   'not_transition'),
#  ('clade_317', 'L11.TTTATGCGTGTGGCTC-1'): (1.085172006087517,
#   2.4760360191542183,
#   'not_transition'),
#  ('clade_634', 'clade_635'): (1.3337223141738612,
#   1.3387229302228367,
#   'not_transition'),
#  ('clade_634', 'L11.CTCTAATAGTGTGAAT-1'): (1.3337223141738612,
#   2.4760354188081064,
#   'not_transition'),
#  ('clade_646', 'clade_647'): (1.0697916903192448,
#   1.07479212757847,
#   'not_transition'),
#  ('clade_646', 'clade_656'): (1.0697916903192448,
#   1.1983844004635664,
#   'not_transition'),
#  ('clade_683', 'clade_684'): (0.9738849182346012,
#   0.9790765321124205,
#   'not_transition'),
#  ('clade_683', 'clade_721'): (0.9738849182346012,
#   1.2376725385635927,
#   'not_transition'),
#  ('clade_727', 'clade_728'): (1.2138398546714162,
#   1.218839854671416,
#   'not_transition'),
#  ('clade_727', 'L11.GGAAAGCTCCCAACGG-1'): (1.2138398546714162,
#   2.476036557993252,
#   'not_transition'),
#  ('clade_760', 'L11.TCGTAGAAGTACGTAA-1'): (2.4710283943595077,
#   2.4760302667923697,
#   'not_transition'),
#  ('clade_760', 'L11.CCACGGACACCTCGGA-1'): (2.4710283943595077,
#   2.4760302667923697,
#   'not_transition'),
#  ...}

# %%
# burst is 1.75 to 2.25 
scaled_intervals = [0.0, 1, 5, 6]
scale_factor = 6/2.47
intervals = [x/scale_factor for x in scaled_intervals]

# %%
epochs = ['Primary Growth', 'Metastasis Burst', 'Late Metastasis']

# %%
# # count the metastasis events in each epoch

# epoch_lineage_count = dict()
# epoch_met_count = dict()
# epoch_reseeding_count = dict()
# for epoch in epochs:
#     epoch_met_count[epoch] = 0
#     epoch_lineage_count[epoch] = 0
#     epoch_reseeding_count[epoch] = 0
    
# for edge in transition_heights:
#     branch_start, branch_end, branch_type = transition_heights[edge]
    
#     # find which epoch it lives in
#     # add to that epoch's count
#     branch_length = branch_end - branch_start
#     branch_interval = pd.Interval(branch_start, branch_end, closed='both')
#     for i, interval_start in enumerate(intervals[:-1]):
#         interval_end = intervals[i+1]
#         interval = pd.Interval(interval_start, interval_end, closed='both')
#         if interval.overlaps(branch_interval):
#             if branch_type == 'p2n_transition':
#                 epoch_met_count[epochs[i]] += 1
#             elif branch_type == 'n2p_transition':
#                 epoch_reseeding_count[epochs[i]] += 1
            
#             # if branch_type == "n2p_transition" or branch_type == "p2n_transition":
#             epoch_lineage_count[epochs[i]] += 1

# %%
# print("Metastasis:", epoch_met_count)
# print("Reseedings:", epoch_reseeding_count)
# print("Lineages:", epoch_lineage_count)
# Out:
# Metastasis: {'Primary Growth': 0, 'Metastasis Burst': 45, 'Late Metastasis': 37}
# Reseedings: {'Primary Growth': 0, 'Metastasis Burst': 27, 'Late Metastasis': 25}
# Lineages: {'Primary Growth': 44, 'Metastasis Burst': 2443, 'Late Metastasis': 1557}

# %%
# 25/(25 + 37), 37/(25 + 37)
# Out:
# (0.4032258064516129, 0.5967741935483871)

# %%
# print("Primary Growth", 0/44/1)
# print("Metastasis Burst", 16/829/2)
# print("Late Metastasis", 45/2364/3)
# Out:
# Primary Growth 0.0
# Metastasis Burst 0.009650180940892641
# Late Metastasis 0.00634517766497462

# %%
# # background rate of metastasis
# (3+12+47)/(86+212+2662)/6
# Out:
# 0.0034909909909909913

# %%
# # bursting window in Metastasis stage
# 12/212/(.5)
# Out:
# 0.11320754716981132

# %%
# # ratio of metastasis burst window to background rate of metastasis
# 0.11320754716981132/0.0034909909909909913
# Out:
# 32.42848447961047

# %%
# (0.009650180940892641-0.00634517766497462)/0.009650180940892641
# Out:
# 0.34248096446700493

# %%
def find_epoch(intervals, epochs, branch_start, branch_end):
    epoch_overlap = []
        
    branch_length = branch_end - branch_start
    branch_interval = pd.Interval(branch_start, branch_end, closed='both')
    for i, interval_start in enumerate(intervals[:-1]):
        interval_end = intervals[i+1]
        interval = pd.Interval(interval_start, interval_end, closed='both')
        epoch_overlap.append(interval.overlaps(branch_interval))
    return epoch_overlap

# %%
# # get all leaf incident edges
# with open("epoch_leaf_stats.csv", "w+") as w:
#     w.write("branch_length,epoch\n")
#     for edge in transition_heights:
#         f, t = edge
#         branch_start, branch_end, branch_type = transition_heights[edge]
#         if not t.startswith('clade') and not t.startswith('root'):
#             # is leaf
#             branch_length = branch_end - branch_start
#             epoch_overlap_bool = find_epoch(intervals, epochs, branch_start, branch_end)
#             for i, is_overlap in enumerate(epoch_overlap_bool):
#                 w.write(','.join([str(xx) for xx in [branch_length, epochs[i]]]) + '\n')
#                 break

# %%
epochs = ['Primary Growth', 'Metastasis', 'Late Metastasis']
# burst is 1.75 to 2.25 
scaled_intervals = [0.0, 1, 3, 6]
scale_factor = 6/2.47
intervals = [x/scale_factor for x in scaled_intervals]
intervals
# Out:
# [0.0, 0.4116666666666667, 1.235, 2.47]

# %%
# get all edges that lie entirely in one epoch
with open("epoch_all_stats.csv", "w+") as w:
    w.write("branch_length,epoch\n")
    for edge in transition_heights:
        f, t = edge
        branch_start, branch_end, branch_type = transition_heights[edge]
        branch_length = branch_end - branch_start
        epoch_overlap_bool = find_epoch(intervals, epochs, branch_start, branch_end)
        # only record if overlaps 1
        if sum(epoch_overlap_bool) == 1:
            for i, bool in enumerate(epoch_overlap_bool):
                if bool: 
                    w.write(','.join([str(xx) for xx in [branch_length, epochs[i]]]) + '\n')

        branch_interval = pd.Interval(branch_start, branch_end, closed='both')
        burst_interval = pd.Interval(1.75, 2.25, closed='both')
        before_burst_interval = pd.Interval(0, 1.75, closed='both')
        after_burst_interval = pd.Interval(2.25, 6, closed='both')
        if burst_interval.overlaps(branch_interval) and not before_burst_interval.overlaps(branch_interval) and not after_burst_interval.overlaps(branch_interval):
            w.write(','.join([str(xx) for xx in [branch_length, 'Metastasis Burst']]) + '\n')

# %%
epoch_met_count, epoch_lineage_count
# Out:
# ({'Primary Growth': 4, 'Metastasis Burst': 13, 'Late Metastasis': 47},
#  {'Primary Growth': 88, 'Metastasis Burst': 527, 'Late Metastasis': 2504})

# %%
print("Primary Growth", 4/88/1.8)
print("Metastasis Burst", 13/527/(2.7 - 1.8))
print("Late Metastasis", 47/2504/(6 - 2.7))
# Out:
# Primary Growth 0.025252525252525252
# Metastasis Burst 0.027408812987560614
# Late Metastasis 0.005687869106399459

# %%
# burst is 1.75 to 2.25 
scaled_intervals = [0.0, 1, 1.75, 2.25, 3, 6]
scale_factor = 6/2.47
intervals = [x/scale_factor for x in scaled_intervals]
intervals
# Out:
# [0.0, 0.4116666666666667, 0.7204166666666667, 0.92625, 1.235, 2.47]

# %%
all_transition_intervals = [transition_heights[x] for x in transition_heights]
# sort by starting 
all_transition_intervals.sort(key=lambda x: x[0])

all_transition_counts = dict()
for interval_start in intervals:
    all_transition_counts[interval_start] = []

# %%
all_transition_counts
# Out:
# {0.0: [],
#  0.4116666666666667: [],
#  0.7204166666666667: [],
#  0.92625: [],
#  1.235: [],
#  2.47: []}

# %%
for i, interval_start in enumerate(intervals[:-1]):
    interval_end = intervals[i+1]
    interval = pd.Interval(interval_start, interval_end, closed='both')    
    interval_list = all_transition_counts[interval_start]
    for i in range(len(all_transition_intervals)):
        branch_start, branch_end, branch_transition_type = all_transition_intervals[i]
        branch_interval = pd.Interval(branch_start, branch_end, closed='both')
        
        if interval.overlaps(branch_interval):
            branch_length = branch_end - branch_start
            interval_list.append(branch_length)
        # else:
        #     break
    print(all_transition_counts)
# Out:
# {0.0: [0.19311067051961742, 0.005, 0.7878975489609431, 0.005, 0.1260013610013078, 0.004999999999999999, 0.11317298282909295, 0.005000000000000001, 0.005000000000000001, 0.0732079371446571, 0.00656203629714415, 0.3426195061621374, 0.15960905777811843, 2.4444676278964788, 0.0050000000000000044, 2.372604046732874, 0.08608758212655923, 0.0050000000000000044, 2.372822605634022, 0.09826523963712627, 0.3421027396523065, 0.007834202777416116, 0.12719259066899338, 0.8834217999120579, 0.2793610480308598, 2.3400213569905084, 0.30096176048765955, 0.2799862732873783, 0.3014199643365111, 1.7764992906932011, 0.46475513319561146, 2.282915814433405, 0.654759545422942, 0.09947074293105412, 0.201510948889362, 0.10509185598437326, 0.10411422024592998, 2.1750866551382932, 2.108410160982241, 2.108410160982241, 0.09390949094370116, 0.34403846468739974, 0.2238929323914972, 0.11500744310954081], 0.4116666666666667: [], 0.7204166666666667: [], 0.92625: [], 1.235: [], 2.47: []}
# {0.0: [0.19311067051961742, 0.005, 0.7878975489609431, 0.005, 0.1260013610013078, 0.004999999999999999, 0.11317298282909295, 0.005000000000000001, 0.005000000000000001, 0.0732079371446571, 0.00656203629714415, 0.3426195061621374, 0.15960905777811843, 2.4444676278964788, 0.0050000000000000044, 2.372604046732874, 0.08608758212655923, 0.0050000000000000044, 2.372822605634022, 0.09826523963712627, 0.3421027396523065, 0.007834202777416116, 0.12719259066899338, 0.8834217999120579, 0.2793610480308598, 2.3400213569905084, 0.30096176048765955, 0.2799862732873783, 0.3014199643365111, 1.7764992906932011, 0.46475513319561146, 2.282915814433405, 0.654759545422942, 0.09947074293105412, 0.201510948889362, 0.10509185598437326, 0.10411422024592998, 2.1750866551382932, 2.108410160982241, 2.108410160982241, 0.09390949094370116, 0.34403846468739974, 0.2238929323914972, 0.11500744310954081], 0.4116666666666667: [0.7878975489609431, 2.4444676278964788, 2.372604046732874, 2.372822605634022, 0.3421027396523065, 0.8834217999120579, 0.2793610480308598, 2.3400213569905084, 0.30096176048765955, 0.2799862732873783, 0.3014199643365111, 1.7764992906932011, 0.46475513319561146, 2.282915814433405, 0.654759545422942, 0.201510948889362, 2.1750866551382932, 2.108410160982241, 2.108410160982241, 0.09390949094370116, 0.34403846468739974, 0.2238929323914972, 0.11500744310954081, 0.005001037309235401, 0.11033461538144929, 0.588123974618552, 2.055659253709271, 0.18580159954465525, 0.2852010105381234, 0.42581986508877484, 2.0117480857332546, 0.4780742944895765, 2.011322954608657, 0.6801604280484297, 0.7225090274254626, 0.5951749150739629, 1.990772597440917, 1.9834386057818496, 1.9834386057818496, 0.12305372723007102, 0.005000265172448781, 0.6787616212306995, 0.0050000000000000044, 1.0495291665679227, 1.9503257047988658, 0.19648278771232475, 1.9459649969530344, 0.0050008472173060925, 0.14467545272108673, 0.4925305242847783, 0.2573951399948291, 0.005004340912644012, 0.11041670380022672, 1.828030973387133, 0.10762271239221477, 0.005002740867382505, 0.005000653247523745, 0.17106235669561043, 0.17967065315190422, 0.4719393684678981, 0.724753132357087, 0.3843457381117571, 1.818160681237794, 0.2803778851628249, 0.33204619641926136], 0.7204166666666667: [], 0.92625: [], 1.235: [], 2.47: []}
# {0.0: [0.19311067051961742, 0.005, 0.7878975489609431, 0.005, 0.1260013610013078, 0.004999999999999999, 0.11317298282909295, 0.005000000000000001, 0.005000000000000001, 0.0732079371446571, 0.00656203629714415, 0.3426195061621374, 0.15960905777811843, 2.4444676278964788, 0.0050000000000000044, 2.372604046732874, 0.08608758212655923, 0.0050000000000000044, 2.372822605634022, 0.09826523963712627, 0.3421027396523065, 0.007834202777416116, 0.12719259066899338, 0.8834217999120579, 0.2793610480308598, 2.3400213569905084, 0.30096176048765955, 0.2799862732873783, 0.3014199643365111, 1.7764992906932011, 0.46475513319561146, 2.282915814433405, 0.654759545422942, 0.09947074293105412, 0.201510948889362, 0.10509185598437326, 0.10411422024592998, 2.1750866551382932, 2.108410160982241, 2.108410160982241, 0.09390949094370116, 0.34403846468739974, 0.2238929323914972, 0.11500744310954081], 0.4116666666666667: [0.7878975489609431, 2.4444676278964788, 2.372604046732874, 2.372822605634022, 0.3421027396523065, 0.8834217999120579, 0.2793610480308598, 2.3400213569905084, 0.30096176048765955, 0.2799862732873783, 0.3014199643365111, 1.7764992906932011, 0.46475513319561146, 2.282915814433405, 0.654759545422942, 0.201510948889362, 2.1750866551382932, 2.108410160982241, 2.108410160982241, 0.09390949094370116, 0.34403846468739974, 0.2238929323914972, 0.11500744310954081, 0.005001037309235401, 0.11033461538144929, 0.588123974618552, 2.055659253709271, 0.18580159954465525, 0.2852010105381234, 0.42581986508877484, 2.0117480857332546, 0.4780742944895765, 2.011322954608657, 0.6801604280484297, 0.7225090274254626, 0.5951749150739629, 1.990772597440917, 1.9834386057818496, 1.9834386057818496, 0.12305372723007102, 0.005000265172448781, 0.6787616212306995, 0.0050000000000000044, 1.0495291665679227, 1.9503257047988658, 0.19648278771232475, 1.9459649969530344, 0.0050008472173060925, 0.14467545272108673, 0.4925305242847783, 0.2573951399948291, 0.005004340912644012, 0.11041670380022672, 1.828030973387133, 0.10762271239221477, 0.005002740867382505, 0.005000653247523745, 0.17106235669561043, 0.17967065315190422, 0.4719393684678981, 0.724753132357087, 0.3843457381117571, 1.818160681237794, 0.2803778851628249, 0.33204619641926136], 0.7204166666666667: [0.7878975489609431, 2.4444676278964788, 2.372604046732874, 2.372822605634022, 0.8834217999120579, 2.3400213569905084, 1.7764992906932011, 2.282915814433405, 0.654759545422942, 2.1750866551382932, 2.108410160982241, 2.108410160982241, 0.588123974618552, 2.055659253709271, 0.2852010105381234, 0.42581986508877484, 2.0117480857332546, 0.4780742944895765, 2.011322954608657, 0.6801604280484297, 0.7225090274254626, 0.5951749150739629, 1.990772597440917, 1.9834386057818496, 1.9834386057818496, 0.6787616212306995, 1.0495291665679227, 1.9503257047988658, 0.19648278771232475, 1.9459649969530344, 0.14467545272108673, 0.4925305242847783, 0.2573951399948291, 0.11041670380022672, 1.828030973387133, 0.10762271239221477, 0.17106235669561043, 0.17967065315190422, 0.4719393684678981, 0.724753132357087, 0.3843457381117571, 1.818160681237794, 0.2803778851628249, 0.33204619641926136, 0.30032135448376873, 1.7494822092407096, 0.1687737769662625, 0.15148551889898143, 0.005001251354261882, 0.12595509743322253, 0.09456162837721416, 0.005028526778994902, 0.747376367157478, 0.5061807746241189, 0.37274145527453084, 1.7153797728069846, 1.7024040604053865, 1.7024040604053865, 0.5970955952415664, 1.6831296699538953, 0.7923246308285363, 0.005002874200899954, 0.3709339947719258, 0.005000029906556014, 0.5231383548727034, 0.005000069334964441, 0.0050000000000000044, 1.6418410207646077, 0.0050006358675036555, 0.005000224125888186, 0.0050000000000000044, 0.4270947971797814, 0.319563058166503, 0.5674780174839009, 0.6859693280377097, 0.005000578681612411, 0.41695445899066164, 0.0050000000000000044, 0.005000528764058987, 0.6835081624002698, 0.23113033199773825, 0.0050000000000000044, 0.0050000000000000044, 0.9484751297972399, 0.00500034441328534, 0.8563650387169572,  ...
# {0.0: [0.19311067051961742, 0.005, 0.7878975489609431, 0.005, 0.1260013610013078, 0.004999999999999999, 0.11317298282909295, 0.005000000000000001, 0.005000000000000001, 0.0732079371446571, 0.00656203629714415, 0.3426195061621374, 0.15960905777811843, 2.4444676278964788, 0.0050000000000000044, 2.372604046732874, 0.08608758212655923, 0.0050000000000000044, 2.372822605634022, 0.09826523963712627, 0.3421027396523065, 0.007834202777416116, 0.12719259066899338, 0.8834217999120579, 0.2793610480308598, 2.3400213569905084, 0.30096176048765955, 0.2799862732873783, 0.3014199643365111, 1.7764992906932011, 0.46475513319561146, 2.282915814433405, 0.654759545422942, 0.09947074293105412, 0.201510948889362, 0.10509185598437326, 0.10411422024592998, 2.1750866551382932, 2.108410160982241, 2.108410160982241, 0.09390949094370116, 0.34403846468739974, 0.2238929323914972, 0.11500744310954081], 0.4116666666666667: [0.7878975489609431, 2.4444676278964788, 2.372604046732874, 2.372822605634022, 0.3421027396523065, 0.8834217999120579, 0.2793610480308598, 2.3400213569905084, 0.30096176048765955, 0.2799862732873783, 0.3014199643365111, 1.7764992906932011, 0.46475513319561146, 2.282915814433405, 0.654759545422942, 0.201510948889362, 2.1750866551382932, 2.108410160982241, 2.108410160982241, 0.09390949094370116, 0.34403846468739974, 0.2238929323914972, 0.11500744310954081, 0.005001037309235401, 0.11033461538144929, 0.588123974618552, 2.055659253709271, 0.18580159954465525, 0.2852010105381234, 0.42581986508877484, 2.0117480857332546, 0.4780742944895765, 2.011322954608657, 0.6801604280484297, 0.7225090274254626, 0.5951749150739629, 1.990772597440917, 1.9834386057818496, 1.9834386057818496, 0.12305372723007102, 0.005000265172448781, 0.6787616212306995, 0.0050000000000000044, 1.0495291665679227, 1.9503257047988658, 0.19648278771232475, 1.9459649969530344, 0.0050008472173060925, 0.14467545272108673, 0.4925305242847783, 0.2573951399948291, 0.005004340912644012, 0.11041670380022672, 1.828030973387133, 0.10762271239221477, 0.005002740867382505, 0.005000653247523745, 0.17106235669561043, 0.17967065315190422, 0.4719393684678981, 0.724753132357087, 0.3843457381117571, 1.818160681237794, 0.2803778851628249, 0.33204619641926136], 0.7204166666666667: [0.7878975489609431, 2.4444676278964788, 2.372604046732874, 2.372822605634022, 0.8834217999120579, 2.3400213569905084, 1.7764992906932011, 2.282915814433405, 0.654759545422942, 2.1750866551382932, 2.108410160982241, 2.108410160982241, 0.588123974618552, 2.055659253709271, 0.2852010105381234, 0.42581986508877484, 2.0117480857332546, 0.4780742944895765, 2.011322954608657, 0.6801604280484297, 0.7225090274254626, 0.5951749150739629, 1.990772597440917, 1.9834386057818496, 1.9834386057818496, 0.6787616212306995, 1.0495291665679227, 1.9503257047988658, 0.19648278771232475, 1.9459649969530344, 0.14467545272108673, 0.4925305242847783, 0.2573951399948291, 0.11041670380022672, 1.828030973387133, 0.10762271239221477, 0.17106235669561043, 0.17967065315190422, 0.4719393684678981, 0.724753132357087, 0.3843457381117571, 1.818160681237794, 0.2803778851628249, 0.33204619641926136, 0.30032135448376873, 1.7494822092407096, 0.1687737769662625, 0.15148551889898143, 0.005001251354261882, 0.12595509743322253, 0.09456162837721416, 0.005028526778994902, 0.747376367157478, 0.5061807746241189, 0.37274145527453084, 1.7153797728069846, 1.7024040604053865, 1.7024040604053865, 0.5970955952415664, 1.6831296699538953, 0.7923246308285363, 0.005002874200899954, 0.3709339947719258, 0.005000029906556014, 0.5231383548727034, 0.005000069334964441, 0.0050000000000000044, 1.6418410207646077, 0.0050006358675036555, 0.005000224125888186, 0.0050000000000000044, 0.4270947971797814, 0.319563058166503, 0.5674780174839009, 0.6859693280377097, 0.005000578681612411, 0.41695445899066164, 0.0050000000000000044, 0.005000528764058987, 0.6835081624002698, 0.23113033199773825, 0.0050000000000000044, 0.0050000000000000044, 0.9484751297972399, 0.00500034441328534, 0.8563650387169572,  ...
# {0.0: [0.19311067051961742, 0.005, 0.7878975489609431, 0.005, 0.1260013610013078, 0.004999999999999999, 0.11317298282909295, 0.005000000000000001, 0.005000000000000001, 0.0732079371446571, 0.00656203629714415, 0.3426195061621374, 0.15960905777811843, 2.4444676278964788, 0.0050000000000000044, 2.372604046732874, 0.08608758212655923, 0.0050000000000000044, 2.372822605634022, 0.09826523963712627, 0.3421027396523065, 0.007834202777416116, 0.12719259066899338, 0.8834217999120579, 0.2793610480308598, 2.3400213569905084, 0.30096176048765955, 0.2799862732873783, 0.3014199643365111, 1.7764992906932011, 0.46475513319561146, 2.282915814433405, 0.654759545422942, 0.09947074293105412, 0.201510948889362, 0.10509185598437326, 0.10411422024592998, 2.1750866551382932, 2.108410160982241, 2.108410160982241, 0.09390949094370116, 0.34403846468739974, 0.2238929323914972, 0.11500744310954081], 0.4116666666666667: [0.7878975489609431, 2.4444676278964788, 2.372604046732874, 2.372822605634022, 0.3421027396523065, 0.8834217999120579, 0.2793610480308598, 2.3400213569905084, 0.30096176048765955, 0.2799862732873783, 0.3014199643365111, 1.7764992906932011, 0.46475513319561146, 2.282915814433405, 0.654759545422942, 0.201510948889362, 2.1750866551382932, 2.108410160982241, 2.108410160982241, 0.09390949094370116, 0.34403846468739974, 0.2238929323914972, 0.11500744310954081, 0.005001037309235401, 0.11033461538144929, 0.588123974618552, 2.055659253709271, 0.18580159954465525, 0.2852010105381234, 0.42581986508877484, 2.0117480857332546, 0.4780742944895765, 2.011322954608657, 0.6801604280484297, 0.7225090274254626, 0.5951749150739629, 1.990772597440917, 1.9834386057818496, 1.9834386057818496, 0.12305372723007102, 0.005000265172448781, 0.6787616212306995, 0.0050000000000000044, 1.0495291665679227, 1.9503257047988658, 0.19648278771232475, 1.9459649969530344, 0.0050008472173060925, 0.14467545272108673, 0.4925305242847783, 0.2573951399948291, 0.005004340912644012, 0.11041670380022672, 1.828030973387133, 0.10762271239221477, 0.005002740867382505, 0.005000653247523745, 0.17106235669561043, 0.17967065315190422, 0.4719393684678981, 0.724753132357087, 0.3843457381117571, 1.818160681237794, 0.2803778851628249, 0.33204619641926136], 0.7204166666666667: [0.7878975489609431, 2.4444676278964788, 2.372604046732874, 2.372822605634022, 0.8834217999120579, 2.3400213569905084, 1.7764992906932011, 2.282915814433405, 0.654759545422942, 2.1750866551382932, 2.108410160982241, 2.108410160982241, 0.588123974618552, 2.055659253709271, 0.2852010105381234, 0.42581986508877484, 2.0117480857332546, 0.4780742944895765, 2.011322954608657, 0.6801604280484297, 0.7225090274254626, 0.5951749150739629, 1.990772597440917, 1.9834386057818496, 1.9834386057818496, 0.6787616212306995, 1.0495291665679227, 1.9503257047988658, 0.19648278771232475, 1.9459649969530344, 0.14467545272108673, 0.4925305242847783, 0.2573951399948291, 0.11041670380022672, 1.828030973387133, 0.10762271239221477, 0.17106235669561043, 0.17967065315190422, 0.4719393684678981, 0.724753132357087, 0.3843457381117571, 1.818160681237794, 0.2803778851628249, 0.33204619641926136, 0.30032135448376873, 1.7494822092407096, 0.1687737769662625, 0.15148551889898143, 0.005001251354261882, 0.12595509743322253, 0.09456162837721416, 0.005028526778994902, 0.747376367157478, 0.5061807746241189, 0.37274145527453084, 1.7153797728069846, 1.7024040604053865, 1.7024040604053865, 0.5970955952415664, 1.6831296699538953, 0.7923246308285363, 0.005002874200899954, 0.3709339947719258, 0.005000029906556014, 0.5231383548727034, 0.005000069334964441, 0.0050000000000000044, 1.6418410207646077, 0.0050006358675036555, 0.005000224125888186, 0.0050000000000000044, 0.4270947971797814, 0.319563058166503, 0.5674780174839009, 0.6859693280377097, 0.005000578681612411, 0.41695445899066164, 0.0050000000000000044, 0.005000528764058987, 0.6835081624002698, 0.23113033199773825, 0.0050000000000000044, 0.0050000000000000044, 0.9484751297972399, 0.00500034441328534, 0.8563650387169572,  ...

# %%
# epochs = ['Primary Growth', 'Pre-Burst', 'Metastasis Burst', 'Post-Burst', 'Late Metastasis']
# with open("epoch_stats.csv", "w+") as w:
#     w.write("interval_start,branch_length,epoch\n")
#     for i, interval_start in enumerate(all_transition_counts):
#         interval_list = all_transition_counts[interval_start]
#         for branch_length in interval_list:    
#             w.write(','.join([str(xx) for xx in [interval_start, branch_length, epochs[i]]]) + '\n')
